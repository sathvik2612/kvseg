# %%
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras import backend as K


#convolutional block
def conv_block(x, kernelsize, filters, dropout, batchnorm=False): 
    conv = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding="same")(x)
    if batchnorm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)
    conv = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding="same")(conv)
    if batchnorm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    return conv


#residual convolutional block
def res_conv_block(x, kernelsize, filters, dropout, batchnorm=False):
    conv1 = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding='same')(x)
    if batchnorm is True:
        conv1 = layers.BatchNormalization(axis=3)(conv1)
    conv1 = layers.Activation('relu')(conv1)    
    conv2 = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding='same')(conv1)
    if batchnorm is True:
        conv2 = layers.BatchNormalization(axis=3)(conv2)
        conv2 = layers.Activation("relu")(conv2)
    if dropout > 0:
        conv2 = layers.Dropout(dropout)(conv2)
        
    #skip connection    
    shortcut = layers.Conv2D(filters, kernel_size=(1, 1), kernel_initializer='he_normal', padding='same')(x)
    if batchnorm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)
    shortcut = layers.Activation("relu")(shortcut)
    respath = layers.add([shortcut, conv2])       
    return respath


#gating signal for attention unit
def gatingsignal(input, out_size, batchnorm=False):
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batchnorm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

#attention unit/block based on soft attention
def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), kernel_initializer='he_normal', padding='same')(x) 
    shape_theta_x = K.int_shape(theta_x)
    phi_g = layers.Conv2D(inter_shape, (1, 1), kernel_initializer='he_normal', padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3), strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]), kernel_initializer='he_normal', padding='same')(phi_g)
    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), kernel_initializer='he_normal', padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg) 
    upsample_psi = layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3), arguments={'repnum': shape_x[3]})(upsample_psi)                          
    y = layers.multiply([upsample_psi, x])
    result = layers.Conv2D(shape_x[3], (1, 1), kernel_initializer='he_normal', padding='same')(y)
    attenblock = layers.BatchNormalization()(result)
    return attenblock

#Simple U-NET
def unetmodel(input_shape, dropout=0.2, batchnorm=True):    
    
    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2
    
    inputs = layers.Input(input_shape)    

    # Downsampling layers
    dn_1 = conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    pool_1 = layers.MaxPooling2D(pool_size=(2,2))(dn_1)
    
    dn_2 = conv_block(pool_1, kernelsize, filters[1], dropout, batchnorm)
    pool_2 = layers.MaxPooling2D(pool_size=(2,2))(dn_2)
    
    dn_3 = conv_block(pool_2, kernelsize, filters[2], dropout, batchnorm)
    pool_3 = layers.MaxPooling2D(pool_size=(2,2))(dn_3)
    
    dn_4 = conv_block(pool_3, kernelsize, filters[3], dropout, batchnorm)
    pool_4 = layers.MaxPooling2D(pool_size=(2,2))(dn_4)
    
    dn_5 = conv_block(pool_4, kernelsize, filters[4], dropout, batchnorm)

    # Upsampling layers   
    up_5 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_5)
    up_5 = layers.concatenate([up_5, dn_4], axis=3)
    up_conv_5 = conv_block(up_5, kernelsize, filters[3], dropout, batchnorm)
    
    up_4 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_5)
    up_4 = layers.concatenate([up_4, dn_3], axis=3)
    up_conv_4 = conv_block(up_4, kernelsize, filters[2], dropout, batchnorm)
       
    up_3 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_4)
    up_3 = layers.concatenate([up_3, dn_2], axis=3)
    up_conv_3 = conv_block(up_3, kernelsize, filters[1], dropout, batchnorm)
    
    up_2 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_3)
    up_2 = layers.concatenate([up_2, dn_1], axis=3)
    up_conv_2 = conv_block(up_2, kernelsize, filters[0], dropout, batchnorm)    
   
    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv_2)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final)  

    model = models.Model(inputs=[inputs], outputs=[outputs])
    model.summary()        
    return model

    
#Attention U-NET
def attentionunet(input_shape, dropout=0.2, batchnorm=True):
    
    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2

    inputs = layers.Input(input_shape) 

    # Downsampling layers    
    dn_1 = conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    pool_1 = layers.MaxPooling2D(pool_size=(2,2))(dn_1)
    
    dn_2 = conv_block(pool_1, kernelsize, filters[1], dropout, batchnorm)
    pool_2 = layers.MaxPooling2D(pool_size=(2,2))(dn_2)
    
    dn_3 = conv_block(pool_2, kernelsize, filters[2], dropout, batchnorm)
    pool_3 = layers.MaxPooling2D(pool_size=(2,2))(dn_3)
    
    dn_4 = conv_block(pool_3, kernelsize, filters[3], dropout, batchnorm)
    pool_4 = layers.MaxPooling2D(pool_size=(2,2))(dn_4)
    
    dn_5 = conv_block(pool_4, kernelsize, filters[4], dropout, batchnorm)

    # Upsampling layers    
    gating_5 = gatingsignal(dn_5, filters[3], batchnorm)
    att_5 = attention_block(dn_4, gating_5, filters[3])
    up_5 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_5)
    up_5 = layers.concatenate([up_5, att_5], axis=3)
    up_conv_5 = conv_block(up_5, kernelsize, filters[3], dropout, batchnorm)
    
    gating_4 = gatingsignal(up_conv_5, filters[2], batchnorm)
    att_4 = attention_block(dn_3, gating_4, filters[2])
    up_4 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_5)
    up_4 = layers.concatenate([up_4, att_4], axis=3)
    up_conv_4 = conv_block(up_4, kernelsize, filters[2], dropout, batchnorm)
   
    gating_3 = gatingsignal(up_conv_4, filters[1], batchnorm)
    att_3 = attention_block(dn_2, gating_3, filters[1])
    up_3 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_4)
    up_3 = layers.concatenate([up_3, att_3], axis=3)
    up_conv_3 = conv_block(up_3, kernelsize, filters[1], dropout, batchnorm)
    
    gating_2 = gatingsignal(up_conv_3, filters[0], batchnorm)
    att_2 = attention_block(dn_1, gating_2, filters[0])
    up_2 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_3)
    up_2 = layers.concatenate([up_2, att_2], axis=3)
    up_conv_2 = conv_block(up_2, kernelsize, filters[0], dropout, batchnorm)
    
    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv_2)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final)  

    model = models.Model(inputs=[inputs], outputs=[outputs])
    model.summary()       
    return model    

#Res-UNET
def residualunet(input_shape, dropout=0.2, batchnorm=True):

    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2

    inputs = layers.Input(input_shape) 

    # Downsampling layers    
    dn_conv1 = conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    dn_pool1 = layers.MaxPooling2D(pool_size=(2,2))(dn_conv1)

    dn_conv2 = res_conv_block(dn_pool1, kernelsize, filters[1], dropout, batchnorm)
    dn_pool2 = layers.MaxPooling2D(pool_size=(2,2))(dn_conv2)

    dn_conv3 = res_conv_block(dn_pool2, kernelsize, filters[2], dropout, batchnorm)
    dn_pool3 = layers.MaxPooling2D(pool_size=(2,2))(dn_conv3)

    dn_conv4 = res_conv_block(dn_pool3, kernelsize, filters[3], dropout, batchnorm)
    dn_pool4 = layers.MaxPooling2D(pool_size=(2,2))(dn_conv4)

    dn_conv5 = res_conv_block(dn_pool4, kernelsize, filters[4], dropout, batchnorm)
   
    # upsampling layers
    up_conv6 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_conv5)
    up_conv6 = layers.concatenate([up_conv6, dn_conv4], axis=3)
    up_conv6 = res_conv_block(up_conv6, kernelsize, filters[3], dropout, batchnorm)

    up_conv7 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv6)
    up_conv7 = layers.concatenate([up_conv7, dn_conv3], axis=3)
    up_conv7 = res_conv_block(up_conv7, kernelsize, filters[2], dropout, batchnorm)

    up_conv8 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv7)
    up_conv8 = layers.concatenate([up_conv8, dn_conv2], axis=3)
    up_conv8 = res_conv_block(up_conv8, kernelsize, filters[1], dropout, batchnorm)

    up_conv9 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv8)
    up_conv9 = layers.concatenate([up_conv9, dn_conv1], axis=3)
    up_conv9 = res_conv_block(up_conv9, kernelsize, filters[0], dropout, batchnorm)


    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv9)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final) 
    
    model = models.Model(inputs=[inputs], outputs=[outputs])
    model.summary()
    return model

#Residual-Attention UNET (RA-UNET)
def residual_attentionunet(input_shape, dropout=0.2, batchnorm=True):
    
    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2
    
    inputs = layers.Input(input_shape)    
    
    # Downsampling layers
    dn_1 = res_conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    pool1 = layers.MaxPooling2D(pool_size=(2,2))(dn_1)

    dn_2 = res_conv_block(pool1, kernelsize, filters[1], dropout, batchnorm)
    pool2 = layers.MaxPooling2D(pool_size=(2,2))(dn_2)

    dn_3 = res_conv_block(pool2, kernelsize, filters[2], dropout, batchnorm)
    pool3 = layers.MaxPooling2D(pool_size=(2,2))(dn_3)

    dn_4 = res_conv_block(pool3, kernelsize, filters[3], dropout, batchnorm)
    pool4 = layers.MaxPooling2D(pool_size=(2,2))(dn_4)

    dn_5 = res_conv_block(pool4, kernelsize, filters[4], dropout, batchnorm)

    # Upsampling layers    
    gating_5 = gatingsignal(dn_5, filters[3], batchnorm)
    att_5 = attention_block(dn_4, gating_5, filters[3])
    up_5 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_5)
    up_5 = layers.concatenate([up_5, att_5], axis=3)
    up_conv_5 = res_conv_block(up_5, kernelsize, filters[3], dropout, batchnorm)
    
    gating_4 = gatingsignal(up_conv_5, filters[2], batchnorm)
    att_4 = attention_block(dn_3, gating_4, filters[2])
    up_4 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_5)
    up_4 = layers.concatenate([up_4, att_4], axis=3)
    up_conv_4 = res_conv_block(up_4, kernelsize, filters[2], dropout, batchnorm)
   
    gating_3 = gatingsignal(up_conv_4, filters[1], batchnorm)
    att_3 = attention_block(dn_2, gating_3, filters[1])
    up_3 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_4)
    up_3 = layers.concatenate([up_3, att_3], axis=3)
    up_conv_3 = res_conv_block(up_3, kernelsize, filters[1], dropout, batchnorm)
    
    gating_2 = gatingsignal(up_conv_3, filters[0], batchnorm)
    att_2 = attention_block(dn_1, gating_2, filters[0])
    up_2 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_3)
    up_2 = layers.concatenate([up_2, att_2], axis=3)
    up_conv_2 = res_conv_block(up_2, kernelsize, filters[0], dropout, batchnorm)
   
    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv_2)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final)  

    model = models.Model(inputs=[inputs], outputs=[outputs])
    model.summary() 
    return model

# %%
from tensorflow.keras import backend as K
from sklearn.metrics import jaccard_score,confusion_matrix


def IoU_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

def IoU_loss(y_true, y_pred):
    return -IoU_coef(y_true, y_pred)
 
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)
 
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)
  
def accuracy(y_true, y_pred):
    cm = confusion_matrix(y_true.flatten(),y_pred.flatten(), labels=[0, 1])
    acc = (cm[0,0]+cm[1,1])/(cm[0,0]+cm[0,1]+cm[1,0]+cm[1,1])
    return acc
  
def IoU(y_true, y_pred, labels = [0, 1]):
   IoU = []
   for label in labels:
      jaccard = jaccard_score(y_pred.flatten(),y_true.flatten(), pos_label=label, average='weighted')
      IoU.append(jaccard)     
   return np.mean(IoU)

# %%
# !pip install patchify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: patchify in /usr/local/lib/python3.7/dist-packages (0.2.3)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.7/dist-packages (from patchify) (1.21.6)

# %%
import os
import cv2
import numpy as np
import skimage.io
from matplotlib import pyplot as plt
from patchify import patchify
from PIL import Image
np.random.seed(0) 


#CLAHE
def clahe_equalized(imgs):    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))    
    imgs_equalized = clahe.apply(imgs)
    return imgs_equalized


path1 = '/content/drive/MyDrive/training/images' #training images directory
path2 = '/content/drive/MyDrive/training/masks' #training masks directory

image_dataset = []
mask_dataset = [] 

patch_size = 512

images = sorted(os.listdir(path1)) 

for i, image_name in enumerate(images):  
   if image_name.endswith(".jpg"):                   
       image = skimage.io.imread(path1+"/"+image_name)  #Read image
       
       image = image[:,:,1] #selecting green channel
       image = clahe_equalized(image) #applying CLAHE
       

       SIZE_X = (image.shape[1]//patch_size)*patch_size #getting size multiple of patch size
       SIZE_Y = (image.shape[0]//patch_size)*patch_size #getting size multiple of patch size
       image = Image.fromarray(image)        
       image = image.resize((512, 512)) #resize image       
       image = np.array(image) 
       patches_img = patchify(image, (patch_size, patch_size), step=patch_size)  #create patches(patch_sizexpatch_sizex1)
            
       for i in range(patches_img.shape[0]):
           for j in range(patches_img.shape[1]):                        
               single_patch_img = patches_img[i,j,:,:]                 
               single_patch_img = (single_patch_img.astype('float32')) / 255.                    
               image_dataset.append(single_patch_img)

masks = sorted(os.listdir(path2))  
for i, mask_name in enumerate(masks):  
    if mask_name.endswith(".jpg"):                  
        mask = skimage.io.imread(path2+"/"+mask_name,as_gray=True)   #Read masks
        
        
        SIZE_X = (mask.shape[1]//patch_size)*patch_size #getting size multiple of patch size
        SIZE_Y = (mask.shape[0]//patch_size)*patch_size #getting size multiple of patch size
        mask = Image.fromarray(mask)        
        mask = mask.resize((512, 512))  #resize image
        mask = np.array(mask)
        patches_mask = patchify(mask, (patch_size, patch_size), step=patch_size)  #create patches(patch_sizexpatch_sizex1)
            
        for i in range(patches_mask.shape[0]):
            for j in range(patches_mask.shape[1]):                            
                single_patch_mask = patches_mask[i,j,:,:]
                single_patch_mask = (single_patch_mask.astype('float32'))/255. 
                mask_dataset.append(single_patch_mask) 
 
image_dataset = np.array(image_dataset)
mask_dataset =  np.array(mask_dataset)
image_dataset = np.expand_dims(image_dataset,axis=-1)
mask_dataset =  np.expand_dims(mask_dataset,axis=-1)


#importing models

from tensorflow.keras.optimizers import Adam


IMG_HEIGHT = patch_size
IMG_WIDTH = patch_size
IMG_CHANNELS = 1
input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

#model = unetmodel(input_shape)
#model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])

model = residualunet(input_shape)
model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])
#model = attentionunet(input_shape)
#model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])
#model = residual_attentionunet(input_shape)
#model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])


#splitting data into 70-30 ratio to validate training performance
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size=0.2, random_state=0)

#train model
history = model.fit(x_train, y_train, 
                    verbose=1,
                    batch_size = 16,
                    validation_data=(x_test, y_test ), 
                    shuffle=False,
                    epochs=100)

#training-validation loss curve
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(7,5))
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'y', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

#training-validation accuracy curve
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(7,5))
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'y', label='Validation Accuracy')
plt.title('Training and validation accuracies')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

#training-validation IoU curve
iou_coef = history.history['IoU_coef']
val_iou_coef = history.history['val_IoU_coef']
plt.figure(figsize=(7,5))
plt.plot(epochs, iou_coef, 'r', label='Training IoU')
plt.plot(epochs, val_iou_coef, 'y', label='Validation IoU')
plt.title('Training and validation IoU coefficients')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

#save model
#model.save('/content/drive/MyDrive/training/retina_Unet_150epochs.hdf5')
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_11 (InputLayer)          [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d_198 (Conv2D)            (None, 512, 512, 16  160         ['input_11[0][0]']
#                                 )
#
#  batch_normalization_198 (Batch  (None, 512, 512, 16  64         ['conv2d_198[0][0]']
#  Normalization)                 )
#
#  activation_198 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_198[0][0]']
#                                 )
#
#  dropout_90 (Dropout)           (None, 512, 512, 16  0           ['activation_198[0][0]']
#                                 )
#
#  conv2d_199 (Conv2D)            (None, 512, 512, 16  2320        ['dropout_90[0][0]']
#                                 )
#
#  batch_normalization_199 (Batch  (None, 512, 512, 16  64         ['conv2d_199[0][0]']
#  Normalization)                 )
#
#  activation_199 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_199[0][0]']
#                                 )
#
#  max_pooling2d_40 (MaxPooling2D  (None, 256, 256, 16  0          ['activation_199[0][0]']
#  )                              )
#
#  conv2d_200 (Conv2D)            (None, 256, 256, 32  4640        ['max_pooling2d_40[0][0]']
#                                 )
#
#  batch_normalization_200 (Batch  (None, 256, 256, 32  128        ['conv2d_200[0][0]']
#  Normalization)                 )
#
#  activation_200 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_200[0][0]']
#                                 )
#
#  conv2d_201 (Conv2D)            (None, 256, 256, 32  9248        ['activation_200[0][0]']
#                                 )
#
#  conv2d_202 (Conv2D)            (None, 256, 256, 32  544         ['max_pooling2d_40[0][0]']
#                                 )
#
#  batch_normalization_201 (Batch  (None, 256, 256, 32  128        ['conv2d_201[0][0]']
#  Normalization)                 )
#
#  batch_normalization_202 (Batch  (None, 256, 256, 32  128        ['conv2d_202[0][0]']
#  Normalization)                 )
#
#  activation_201 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_201[0][0]']
#                                 )
#
#  activation_202 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_202[0][0]']
#                                 )
#
#  dropout_91 (Dropout)           (None, 256, 256, 32  0           ['activation_201[0][0]']
#                                 )
#
#  add_8 (Add)                    (None, 256, 256, 32  0           ['activation_202[0][0]',
#                                 )                                 'dropout_91[0][0]']
#
#  max_pooling2d_41 (MaxPooling2D  (None, 128, 128, 32  0          ['add_8[0][0]']
#  )                              )
#
#  conv2d_203 (Conv2D)            (None, 128, 128, 64  18496       ['max_pooling2d_41[0][0]']
#                                 )
#
#  batch_normalization_203 (Batch  (None, 128, 128, 64  256        ['conv2d_203[0][0]']
#  Normalization)                 )
#
#  activation_203 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_203[0][0]']
#                                 )
#
#  conv2d_204 (Conv2D)            (None, 128, 128, 64  36928       ['activation_203[0][0]']
#                                 )
#
#  conv2d_205 (Conv2D)            (None, 128, 128, 64  2112        ['max_pooling2d_41[0][0]']
#                                 )
#
#  batch_normalization_204 (Batch  (None, 128, 128, 64  256        ['conv2d_204[0][0]']
#  Normalization)                 )
#
#  batch_normalization_205 (Batch  (None, 128, 128, 64  256        ['conv2d_205[0][0]']
#  Normalization)                 )
#
#  activation_204 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_204[0][0]']
#                                 )
#
#  activation_205 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_205[0][0]']
#                                 )
#
#  dropout_92 (Dropout)           (None, 128, 128, 64  0           ['activation_204[0][0]']
#                                 )
#
#  add_9 (Add)                    (None, 128, 128, 64  0           ['activation_205[0][0]',
#                                 )                                 'dropout_92[0][0]']
#
#  max_pooling2d_42 (MaxPooling2D  (None, 64, 64, 64)  0           ['add_9[0][0]']
#  )
#
#  conv2d_206 (Conv2D)            (None, 64, 64, 128)  73856       ['max_pooling2d_42[0][0]']
#
#  batch_normalization_206 (Batch  (None, 64, 64, 128)  512        ['conv2d_206[0][0]']
#  Normalization)
#
#  activation_206 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_206[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 64, 64, 128)  147584      ['activation_206[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 64, 64, 128)  8320        ['max_pooling2d_42[0][0]']
#
#  batch_normalization_207 (Batch  (None, 64, 64, 128)  512        ['conv2d_207[0][0]']
#  Normalization)
#
#  batch_normalization_208 (Batch  (None, 64, 64, 128)  512        ['conv2d_208[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_207[0][0]']
#
#  activation_208 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_208[0][0]']
#
#  dropout_93 (Dropout)           (None, 64, 64, 128)  0           ['activation_207[0][0]']
#
#  add_10 (Add)                   (None, 64, 64, 128)  0           ['activation_208[0][0]',
#                                                                   'dropout_93[0][0]']
#
#  max_pooling2d_43 (MaxPooling2D  (None, 32, 32, 128)  0          ['add_10[0][0]']
#  )
#
#  conv2d_209 (Conv2D)            (None, 32, 32, 256)  295168      ['max_pooling2d_43[0][0]']
#
#  batch_normalization_209 (Batch  (None, 32, 32, 256)  1024       ['conv2d_209[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_209[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 32, 32, 256)  590080      ['activation_209[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 32, 32, 256)  33024       ['max_pooling2d_43[0][0]']
#
#  batch_normalization_210 (Batch  (None, 32, 32, 256)  1024       ['conv2d_210[0][0]']
#  Normalization)
#
#  batch_normalization_211 (Batch  (None, 32, 32, 256)  1024       ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_210 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_210[0][0]']
#
#  activation_211 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_211[0][0]']
#
#  dropout_94 (Dropout)           (None, 32, 32, 256)  0           ['activation_210[0][0]']
#
#  add_11 (Add)                   (None, 32, 32, 256)  0           ['activation_211[0][0]',
#                                                                   'dropout_94[0][0]']
#
#  up_sampling2d_40 (UpSampling2D  (None, 64, 64, 256)  0          ['add_11[0][0]']
#  )
#
#  concatenate_40 (Concatenate)   (None, 64, 64, 384)  0           ['up_sampling2d_40[0][0]',
#                                                                   'add_10[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 64, 64, 128)  442496      ['concatenate_40[0][0]']
#
#  batch_normalization_212 (Batch  (None, 64, 64, 128)  512        ['conv2d_212[0][0]']
#  Normalization)
#
#  activation_212 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_212[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 64, 64, 128)  147584      ['activation_212[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 64, 64, 128)  49280       ['concatenate_40[0][0]']
#
#  batch_normalization_213 (Batch  (None, 64, 64, 128)  512        ['conv2d_213[0][0]']
#  Normalization)
#
#  batch_normalization_214 (Batch  (None, 64, 64, 128)  512        ['conv2d_214[0][0]']
#  Normalization)
#
#  activation_213 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_213[0][0]']
#
#  activation_214 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_214[0][0]']
#
#  dropout_95 (Dropout)           (None, 64, 64, 128)  0           ['activation_213[0][0]']
#
#  add_12 (Add)                   (None, 64, 64, 128)  0           ['activation_214[0][0]',
#                                                                   'dropout_95[0][0]']
#
#  up_sampling2d_41 (UpSampling2D  (None, 128, 128, 12  0          ['add_12[0][0]']
#  )                              8)
#
#  concatenate_41 (Concatenate)   (None, 128, 128, 19  0           ['up_sampling2d_41[0][0]',
#                                 2)                                'add_9[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 128, 128, 64  110656      ['concatenate_41[0][0]']
#                                 )
#
#  batch_normalization_215 (Batch  (None, 128, 128, 64  256        ['conv2d_215[0][0]']
#  Normalization)                 )
#
#  activation_215 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_215[0][0]']
#                                 )
#
#  conv2d_216 (Conv2D)            (None, 128, 128, 64  36928       ['activation_215[0][0]']
#                                 )
#
#  conv2d_217 (Conv2D)            (None, 128, 128, 64  12352       ['concatenate_41[0][0]']
#                                 )
#
#  batch_normalization_216 (Batch  (None, 128, 128, 64  256        ['conv2d_216[0][0]']
#  Normalization)                 )
#
#  batch_normalization_217 (Batch  (None, 128, 128, 64  256        ['conv2d_217[0][0]']
#  Normalization)                 )
#
#  activation_216 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_216[0][0]']
#                                 )
#
#  activation_217 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_217[0][0]']
#                                 )
#
#  dropout_96 (Dropout)           (None, 128, 128, 64  0           ['activation_216[0][0]']
#                                 )
#
#  add_13 (Add)                   (None, 128, 128, 64  0           ['activation_217[0][0]',
#                                 )                                 'dropout_96[0][0]']
#
#  up_sampling2d_42 (UpSampling2D  (None, 256, 256, 64  0          ['add_13[0][0]']
#  )                              )
#
#  concatenate_42 (Concatenate)   (None, 256, 256, 96  0           ['up_sampling2d_42[0][0]',
#                                 )                                 'add_8[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 256, 256, 32  27680       ['concatenate_42[0][0]']
#                                 )
#
#  batch_normalization_218 (Batch  (None, 256, 256, 32  128        ['conv2d_218[0][0]']
#  Normalization)                 )
#
#  activation_218 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_218[0][0]']
#                                 )
#
#  conv2d_219 (Conv2D)            (None, 256, 256, 32  9248        ['activation_218[0][0]']
#                                 )
#
#  conv2d_220 (Conv2D)            (None, 256, 256, 32  3104        ['concatenate_42[0][0]']
#                                 )
#
#  batch_normalization_219 (Batch  (None, 256, 256, 32  128        ['conv2d_219[0][0]']
#  Normalization)                 )
#
#  batch_normalization_220 (Batch  (None, 256, 256, 32  128        ['conv2d_220[0][0]']
#  Normalization)                 )
#
#  activation_219 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_219[0][0]']
#                                 )
#
#  activation_220 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_220[0][0]']
#                                 )
#
#  dropout_97 (Dropout)           (None, 256, 256, 32  0           ['activation_219[0][0]']
#                                 )
#
#  add_14 (Add)                   (None, 256, 256, 32  0           ['activation_220[0][0]',
#                                 )                                 'dropout_97[0][0]']
#
#  up_sampling2d_43 (UpSampling2D  (None, 512, 512, 32  0          ['add_14[0][0]']
#  )                              )
#
#  concatenate_43 (Concatenate)   (None, 512, 512, 48  0           ['up_sampling2d_43[0][0]',
#                                 )                                 'activation_199[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 512, 512, 16  6928        ['concatenate_43[0][0]']
#                                 )
#
#  batch_normalization_221 (Batch  (None, 512, 512, 16  64         ['conv2d_221[0][0]']
#  Normalization)                 )
#
#  activation_221 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_221[0][0]']
#                                 )
#
#  conv2d_222 (Conv2D)            (None, 512, 512, 16  2320        ['activation_221[0][0]']
#                                 )
#
#  conv2d_223 (Conv2D)            (None, 512, 512, 16  784         ['concatenate_43[0][0]']
#                                 )
#
#  batch_normalization_222 (Batch  (None, 512, 512, 16  64         ['conv2d_222[0][0]']
#  Normalization)                 )
#
#  batch_normalization_223 (Batch  (None, 512, 512, 16  64         ['conv2d_223[0][0]']
#  Normalization)                 )
#
#  activation_222 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_222[0][0]']
#                                 )
#
#  activation_223 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_223[0][0]']
#                                 )
#
#  dropout_98 (Dropout)           (None, 512, 512, 16  0           ['activation_222[0][0]']
#                                 )
#
#  add_15 (Add)                   (None, 512, 512, 16  0           ['activation_223[0][0]',
#                                 )                                 'dropout_98[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 512, 512, 1)  17          ['add_15[0][0]']
#
#  batch_normalization_224 (Batch  (None, 512, 512, 1)  4          ['conv2d_224[0][0]']
#  Normalization)
#
#  activation_224 (Activation)    (None, 512, 512, 1)  0           ['batch_normalization_224[0][0]']
#
# ==================================================================================================
# Total params: 2,080,629
# Trainable params: 2,076,243
# Non-trainable params: 4,386
# __________________________________________________________________________________________________
# Epoch 1/100
# 50/50 [==============================] - 30s 528ms/step - loss: -8.2756e-04 - accuracy: 0.5481 - IoU_coef: 8.2756e-04 - val_loss: -7.4808e-04 - val_accuracy: 0.2502 - val_IoU_coef: 7.4622e-04
# Epoch 2/100
# 50/50 [==============================] - 25s 508ms/step - loss: -9.0401e-04 - accuracy: 0.6083 - IoU_coef: 9.0401e-04 - val_loss: -6.5860e-04 - val_accuracy: 0.7928 - val_IoU_coef: 6.6030e-04
# Epoch 3/100
# 50/50 [==============================] - 25s 508ms/step - loss: -9.5153e-04 - accuracy: 0.6310 - IoU_coef: 9.5153e-04 - val_loss: -7.5708e-04 - val_accuracy: 0.4586 - val_IoU_coef: 7.5787e-04
# Epoch 4/100
# 50/50 [==============================] - 25s 508ms/step - loss: -9.9670e-04 - accuracy: 0.6522 - IoU_coef: 9.9670e-04 - val_loss: -6.6232e-04 - val_accuracy: 0.8205 - val_IoU_coef: 6.6390e-04
# Epoch 5/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0010 - accuracy: 0.6711 - IoU_coef: 0.0010 - val_loss: -6.5128e-04 - val_accuracy: 0.8210 - val_IoU_coef: 6.5208e-04
# Epoch 6/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0011 - accuracy: 0.6860 - IoU_coef: 0.0011 - val_loss: -6.5198e-04 - val_accuracy: 0.8208 - val_IoU_coef: 6.5329e-04
# Epoch 7/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0011 - accuracy: 0.6980 - IoU_coef: 0.0011 - val_loss: -6.3279e-04 - val_accuracy: 0.8302 - val_IoU_coef: 6.3232e-04
# Epoch 8/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0012 - accuracy: 0.7181 - IoU_coef: 0.0012 - val_loss: -6.3486e-04 - val_accuracy: 0.8290 - val_IoU_coef: 6.3577e-04
# Epoch 9/100
# 50/50 [==============================] - 25s 509ms/step - loss: -0.0013 - accuracy: 0.7278 - IoU_coef: 0.0013 - val_loss: -6.2390e-04 - val_accuracy: 0.8303 - val_IoU_coef: 6.2362e-04
# Epoch 10/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0013 - accuracy: 0.7419 - IoU_coef: 0.0013 - val_loss: -6.8812e-04 - val_accuracy: 0.8297 - val_IoU_coef: 6.9328e-04
# Epoch 11/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0014 - accuracy: 0.7543 - IoU_coef: 0.0014 - val_loss: -6.5928e-04 - val_accuracy: 0.8301 - val_IoU_coef: 6.6347e-04
# Epoch 12/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0014 - accuracy: 0.7589 - IoU_coef: 0.0014 - val_loss: -6.9121e-04 - val_accuracy: 0.8302 - val_IoU_coef: 6.9690e-04
# Epoch 13/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0015 - accuracy: 0.7655 - IoU_coef: 0.0015 - val_loss: -8.4641e-04 - val_accuracy: 0.8286 - val_IoU_coef: 8.5779e-04
# Epoch 14/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0016 - accuracy: 0.7759 - IoU_coef: 0.0016 - val_loss: -9.9058e-04 - val_accuracy: 0.8284 - val_IoU_coef: 9.9743e-04
# Epoch 15/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0017 - accuracy: 0.7813 - IoU_coef: 0.0017 - val_loss: -0.0011 - val_accuracy: 0.8263 - val_IoU_coef: 0.0012
# Epoch 16/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0017 - accuracy: 0.7870 - IoU_coef: 0.0017 - val_loss: -9.4219e-04 - val_accuracy: 0.8294 - val_IoU_coef: 9.4846e-04
# Epoch 17/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0018 - accuracy: 0.7897 - IoU_coef: 0.0018 - val_loss: -8.3300e-04 - val_accuracy: 0.8299 - val_IoU_coef: 8.3885e-04
# Epoch 18/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0019 - accuracy: 0.7941 - IoU_coef: 0.0019 - val_loss: -9.4735e-04 - val_accuracy: 0.8300 - val_IoU_coef: 9.5463e-04
# Epoch 19/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0019 - accuracy: 0.7979 - IoU_coef: 0.0019 - val_loss: -8.5976e-04 - val_accuracy: 0.8300 - val_IoU_coef: 8.7021e-04
# Epoch 20/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0020 - accuracy: 0.7993 - IoU_coef: 0.0020 - val_loss: -6.7560e-04 - val_accuracy: 0.8303 - val_IoU_coef: 6.7781e-04
# Epoch 21/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0021 - accuracy: 0.8038 - IoU_coef: 0.0021 - val_loss: -0.0013 - val_accuracy: 0.8290 - val_IoU_coef: 0.0013
# Epoch 22/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0022 - accuracy: 0.8065 - IoU_coef: 0.0022 - val_loss: -0.0016 - val_accuracy: 0.8253 - val_IoU_coef: 0.0017
# Epoch 23/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0022 - accuracy: 0.8095 - IoU_coef: 0.0022 - val_loss: -0.0016 - val_accuracy: 0.8273 - val_IoU_coef: 0.0016
# Epoch 24/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0023 - accuracy: 0.8116 - IoU_coef: 0.0023 - val_loss: -9.5744e-04 - val_accuracy: 0.8301 - val_IoU_coef: 9.6502e-04
# Epoch 25/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0024 - accuracy: 0.8145 - IoU_coef: 0.0024 - val_loss: -0.0015 - val_accuracy: 0.8291 - val_IoU_coef: 0.0015
# Epoch 26/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0024 - accuracy: 0.8163 - IoU_coef: 0.0024 - val_loss: -0.0018 - val_accuracy: 0.8267 - val_IoU_coef: 0.0018
# Epoch 27/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0025 - accuracy: 0.8183 - IoU_coef: 0.0025 - val_loss: -0.0011 - val_accuracy: 0.8301 - val_IoU_coef: 0.0011
# Epoch 28/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0026 - accuracy: 0.8203 - IoU_coef: 0.0026 - val_loss: -0.0016 - val_accuracy: 0.8291 - val_IoU_coef: 0.0016
# Epoch 29/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0026 - accuracy: 0.8206 - IoU_coef: 0.0026 - val_loss: -0.0023 - val_accuracy: 0.8229 - val_IoU_coef: 0.0023
# Epoch 30/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0027 - accuracy: 0.8210 - IoU_coef: 0.0027 - val_loss: -0.0022 - val_accuracy: 0.7921 - val_IoU_coef: 0.0022
# Epoch 31/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0028 - accuracy: 0.8221 - IoU_coef: 0.0028 - val_loss: -0.0021 - val_accuracy: 0.8244 - val_IoU_coef: 0.0021
# Epoch 32/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0028 - accuracy: 0.8239 - IoU_coef: 0.0028 - val_loss: -0.0014 - val_accuracy: 0.8302 - val_IoU_coef: 0.0014
# Epoch 33/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0029 - accuracy: 0.8242 - IoU_coef: 0.0029 - val_loss: -0.0011 - val_accuracy: 0.8303 - val_IoU_coef: 0.0011
# Epoch 34/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0029 - accuracy: 0.8247 - IoU_coef: 0.0029 - val_loss: -0.0014 - val_accuracy: 0.8300 - val_IoU_coef: 0.0014
# Epoch 35/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0030 - accuracy: 0.8254 - IoU_coef: 0.0030 - val_loss: -0.0012 - val_accuracy: 0.8303 - val_IoU_coef: 0.0012
# Epoch 36/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0030 - accuracy: 0.8261 - IoU_coef: 0.0030 - val_loss: -0.0013 - val_accuracy: 0.8301 - val_IoU_coef: 0.0013
# Epoch 37/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0031 - accuracy: 0.8267 - IoU_coef: 0.0031 - val_loss: -0.0013 - val_accuracy: 0.8302 - val_IoU_coef: 0.0013
# Epoch 38/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0031 - accuracy: 0.8271 - IoU_coef: 0.0031 - val_loss: -0.0022 - val_accuracy: 0.8285 - val_IoU_coef: 0.0022
# Epoch 39/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0032 - accuracy: 0.8276 - IoU_coef: 0.0032 - val_loss: -0.0018 - val_accuracy: 0.8297 - val_IoU_coef: 0.0018
# Epoch 40/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0032 - accuracy: 0.8279 - IoU_coef: 0.0032 - val_loss: -0.0013 - val_accuracy: 0.8303 - val_IoU_coef: 0.0014
# Epoch 41/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0032 - accuracy: 0.8281 - IoU_coef: 0.0032 - val_loss: -0.0017 - val_accuracy: 0.8300 - val_IoU_coef: 0.0017
# Epoch 42/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0033 - accuracy: 0.8283 - IoU_coef: 0.0033 - val_loss: -0.0021 - val_accuracy: 0.8294 - val_IoU_coef: 0.0021
# Epoch 43/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0033 - accuracy: 0.8286 - IoU_coef: 0.0033 - val_loss: -0.0016 - val_accuracy: 0.8303 - val_IoU_coef: 0.0017
# Epoch 44/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0033 - accuracy: 0.8288 - IoU_coef: 0.0033 - val_loss: -0.0026 - val_accuracy: 0.8289 - val_IoU_coef: 0.0026
# Epoch 45/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0033 - accuracy: 0.8287 - IoU_coef: 0.0033 - val_loss: -0.0024 - val_accuracy: 0.8283 - val_IoU_coef: 0.0025
# Epoch 46/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0034 - accuracy: 0.8289 - IoU_coef: 0.0034 - val_loss: -0.0023 - val_accuracy: 0.8298 - val_IoU_coef: 0.0023
# Epoch 47/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0034 - accuracy: 0.8288 - IoU_coef: 0.0034 - val_loss: -0.0026 - val_accuracy: 0.8293 - val_IoU_coef: 0.0026
# Epoch 48/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0034 - accuracy: 0.8291 - IoU_coef: 0.0034 - val_loss: -0.0022 - val_accuracy: 0.8298 - val_IoU_coef: 0.0022
# Epoch 49/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0034 - accuracy: 0.8292 - IoU_coef: 0.0034 - val_loss: -0.0022 - val_accuracy: 0.8297 - val_IoU_coef: 0.0022
# Epoch 50/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0035 - accuracy: 0.8293 - IoU_coef: 0.0035 - val_loss: -0.0027 - val_accuracy: 0.8277 - val_IoU_coef: 0.0028
# Epoch 51/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0035 - accuracy: 0.8294 - IoU_coef: 0.0035 - val_loss: -0.0029 - val_accuracy: 0.8284 - val_IoU_coef: 0.0029
# Epoch 52/100
# 50/50 [==============================] - 25s 509ms/step - loss: -0.0035 - accuracy: 0.8297 - IoU_coef: 0.0035 - val_loss: -0.0029 - val_accuracy: 0.8281 - val_IoU_coef: 0.0029
# Epoch 53/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0035 - accuracy: 0.8296 - IoU_coef: 0.0035 - val_loss: -0.0029 - val_accuracy: 0.8260 - val_IoU_coef: 0.0029
# Epoch 54/100
# 50/50 [==============================] - 25s 510ms/step - loss: -0.0035 - accuracy: 0.8299 - IoU_coef: 0.0035 - val_loss: -0.0026 - val_accuracy: 0.8299 - val_IoU_coef: 0.0026
# Epoch 55/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0036 - accuracy: 0.8298 - IoU_coef: 0.0036 - val_loss: -0.0029 - val_accuracy: 0.8295 - val_IoU_coef: 0.0029
# Epoch 56/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0036 - accuracy: 0.8299 - IoU_coef: 0.0036 - val_loss: -0.0028 - val_accuracy: 0.8295 - val_IoU_coef: 0.0028
# Epoch 57/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0036 - accuracy: 0.8299 - IoU_coef: 0.0036 - val_loss: -0.0026 - val_accuracy: 0.8301 - val_IoU_coef: 0.0026
# Epoch 58/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0036 - accuracy: 0.8298 - IoU_coef: 0.0036 - val_loss: -0.0031 - val_accuracy: 0.8280 - val_IoU_coef: 0.0031
# Epoch 59/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0036 - accuracy: 0.8300 - IoU_coef: 0.0036 - val_loss: -0.0029 - val_accuracy: 0.8301 - val_IoU_coef: 0.0029
# Epoch 60/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0036 - accuracy: 0.8300 - IoU_coef: 0.0036 - val_loss: -0.0029 - val_accuracy: 0.8299 - val_IoU_coef: 0.0029
# Epoch 61/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0036 - accuracy: 0.8301 - IoU_coef: 0.0036 - val_loss: -0.0032 - val_accuracy: 0.8269 - val_IoU_coef: 0.0032
# Epoch 62/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0036 - accuracy: 0.8302 - IoU_coef: 0.0036 - val_loss: -0.0032 - val_accuracy: 0.8289 - val_IoU_coef: 0.0032
# Epoch 63/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0037 - accuracy: 0.8302 - IoU_coef: 0.0037 - val_loss: -0.0032 - val_accuracy: 0.8277 - val_IoU_coef: 0.0032
# Epoch 64/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0037 - accuracy: 0.8302 - IoU_coef: 0.0037 - val_loss: -0.0031 - val_accuracy: 0.8284 - val_IoU_coef: 0.0031
# Epoch 65/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0037 - accuracy: 0.8302 - IoU_coef: 0.0037 - val_loss: -0.0031 - val_accuracy: 0.8300 - val_IoU_coef: 0.0031
# Epoch 66/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0037 - accuracy: 0.8302 - IoU_coef: 0.0037 - val_loss: -0.0032 - val_accuracy: 0.8284 - val_IoU_coef: 0.0032
# Epoch 67/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0037 - accuracy: 0.8302 - IoU_coef: 0.0037 - val_loss: -0.0033 - val_accuracy: 0.8284 - val_IoU_coef: 0.0033
# Epoch 68/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0037 - accuracy: 0.8303 - IoU_coef: 0.0037 - val_loss: -0.0033 - val_accuracy: 0.8272 - val_IoU_coef: 0.0033
# Epoch 69/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0037 - accuracy: 0.8303 - IoU_coef: 0.0037 - val_loss: -0.0033 - val_accuracy: 0.8280 - val_IoU_coef: 0.0033
# Epoch 70/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0037 - accuracy: 0.8303 - IoU_coef: 0.0037 - val_loss: -0.0033 - val_accuracy: 0.8282 - val_IoU_coef: 0.0033
# Epoch 71/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0037 - accuracy: 0.8303 - IoU_coef: 0.0037 - val_loss: -0.0033 - val_accuracy: 0.8281 - val_IoU_coef: 0.0033
# Epoch 72/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0037 - accuracy: 0.8303 - IoU_coef: 0.0037 - val_loss: -0.0034 - val_accuracy: 0.8287 - val_IoU_coef: 0.0034
# Epoch 73/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0037 - accuracy: 0.8303 - IoU_coef: 0.0037 - val_loss: -0.0034 - val_accuracy: 0.8281 - val_IoU_coef: 0.0034
# Epoch 74/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0037 - accuracy: 0.8303 - IoU_coef: 0.0037 - val_loss: -0.0034 - val_accuracy: 0.8288 - val_IoU_coef: 0.0034
# Epoch 75/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0037 - accuracy: 0.8303 - IoU_coef: 0.0037 - val_loss: -0.0034 - val_accuracy: 0.8284 - val_IoU_coef: 0.0034
# Epoch 76/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8283 - val_IoU_coef: 0.0034
# Epoch 77/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0032 - val_accuracy: 0.8296 - val_IoU_coef: 0.0033
# Epoch 78/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0033 - val_accuracy: 0.8297 - val_IoU_coef: 0.0033
# Epoch 79/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8263 - val_IoU_coef: 0.0034
# Epoch 80/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0033 - val_accuracy: 0.8297 - val_IoU_coef: 0.0033
# Epoch 81/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8279 - val_IoU_coef: 0.0035
# Epoch 82/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8299 - val_IoU_coef: 0.0034
# Epoch 83/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8280 - val_IoU_coef: 0.0035
# Epoch 84/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8288 - val_IoU_coef: 0.0035
# Epoch 85/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8294 - val_IoU_coef: 0.0034
# Epoch 86/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8286 - val_IoU_coef: 0.0035
# Epoch 87/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8282 - val_IoU_coef: 0.0035
# Epoch 88/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8285 - val_IoU_coef: 0.0035
# Epoch 89/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8296 - val_IoU_coef: 0.0035
# Epoch 90/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8286 - val_IoU_coef: 0.0035
# Epoch 91/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8293 - val_IoU_coef: 0.0035
# Epoch 92/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8236 - val_IoU_coef: 0.0034
# Epoch 93/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0032 - val_accuracy: 0.8203 - val_IoU_coef: 0.0033
# Epoch 94/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0036 - val_accuracy: 0.8289 - val_IoU_coef: 0.0036
# Epoch 95/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8297 - val_IoU_coef: 0.0035
# Epoch 96/100
# 50/50 [==============================] - 25s 508ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8276 - val_IoU_coef: 0.0035
# Epoch 97/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8294 - val_IoU_coef: 0.0035
# Epoch 98/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8298 - val_IoU_coef: 0.0035
# Epoch 99/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0036 - val_accuracy: 0.8291 - val_IoU_coef: 0.0036
# Epoch 100/100
# 50/50 [==============================] - 25s 507ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0036 - val_accuracy: 0.8294 - val_IoU_coef: 0.0036

# %%
model.save('model-residualunet12.h5')

# %%
import os
import cv2
import numpy as np
import skimage.io
from matplotlib import pyplot as plt
from patchify import patchify, unpatchify
np.random.seed(0)

# CLAHE
def clahe_equalized(imgs):    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))    
    imgs_equalized = clahe.apply(imgs)
    return imgs_equalized

patch_size = 512

#loading model architectures

from tensorflow.keras.optimizers import Adam


IMG_HEIGHT = patch_size
IMG_WIDTH = patch_size
IMG_CHANNELS = 1

input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

model = residualunet(input_shape) #/residualunet(input_shape)/attentionunet(input_shape)/attention_residualunet(input_shape) 
model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])
model.load_weights('/content/model-residualunet12.h5') #loading weights


path1 = '/content/drive/MyDrive/training/images/'    #test dataset images directory path
path2 = '/content/drive/MyDrive/training/masks/'     #test dataset mask directory path


from sklearn.metrics import jaccard_score,confusion_matrix

testimg = []
ground_truth = []
prediction = []
global_IoU = []
global_accuracy = []

testimages = sorted(os.listdir(path1))
testmasks =  sorted(os.listdir(path2))

for idx, image_name in enumerate(testimages):  
   if image_name.endswith(".jpg"):  
      predicted_patches = []
      test_img = skimage.io.imread(path1+"/"+image_name)
     
      test = test_img[:,:,1] #selecting green channel
      test = clahe_equalized(test) #applying CLAHE
      SIZE_X = (test_img.shape[1]//patch_size)*patch_size #getting size multiple of patch size
      SIZE_Y = (test_img.shape[0]//patch_size)*patch_size #getting size multiple of patch size
      test = cv2.resize(test, (SIZE_X, SIZE_Y))
      testimg.append(test)           
      test = np.array(test)

      patches = patchify(test, (patch_size, patch_size), step=patch_size) #create patches(patch_sizexpatch_sizex1)

      for i in range(patches.shape[0]):
                for j in range(patches.shape[1]):
                  single_patch = patches[i,j,:,:]
                  single_patch_norm = (single_patch.astype('float32')) / 255.
                  single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
                  single_patch_input = np.expand_dims(single_patch_norm, 0)
                  single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8) #predict on single patch
                  predicted_patches.append(single_patch_prediction)
      predicted_patches = np.array(predicted_patches)
      predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patch_size,patch_size) )
      reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) #join patches to form whole img
      prediction.append(reconstructed_image) 

      groundtruth=[]
      groundtruth = skimage.io.imread(path2+'/'+testmasks[idx]) #reading mask of the test img      
      SIZE_X = (groundtruth.shape[1]//patch_size)*patch_size 
      SIZE_Y = (groundtruth.shape[0]//patch_size)*patch_size  
      groundtruth = cv2.resize(groundtruth, (SIZE_X, SIZE_Y))  
      ground_truth.append(groundtruth)

      y_true = groundtruth
      y_pred = reconstructed_image
      labels = [0, 1]
      IoU = []
      for label in labels:
          jaccard = jaccard_score(y_pred.flatten(),y_true.flatten(), pos_label=label, average='weighted')
          IoU.append(jaccard)
      IoU = np.mean(IoU) #jacard/IoU of single image
      global_IoU.append(IoU)

      cm=[]
      accuracy = []
      cm = confusion_matrix(y_true.flatten(),y_pred.flatten(), labels=[0, 1])
      accuracy = (cm[0,0]+cm[1,1])/(cm[0,0]+cm[0,1]+cm[1,0]+cm[1,1]) #accuracy of single image
      global_accuracy.append(accuracy)


avg_acc =  np.mean(global_accuracy)
mean_IoU = np.mean(global_IoU)

print('Average accuracy is',avg_acc)
print('mean IoU is',mean_IoU)






#prediction on single image
from datetime import datetime 
reconstructed_image = []
test_img = skimage.io.imread('/content/drive/MyDrive/DRIVE/test/images/01_test.tif') #test image

predicted_patches = []
start = datetime.now()   

test = test_img[:,:,1] #selecting green channel
test = clahe_equalized(test) #applying CLAHE
SIZE_X = (test_img.shape[1]//patch_size)*patch_size #getting size multiple of patch size
SIZE_Y = (test_img.shape[0]//patch_size)*patch_size #getting size multiple of patch size
test = cv2.resize(test, (SIZE_X, SIZE_Y))        
test = np.array(test)
patches = patchify(test, (patch_size, patch_size), step=patch_size) #create patches(patch_sizexpatch_sizex1)

for i in range(patches.shape[0]):
      for j in range(patches.shape[1]):
          single_patch = patches[i,j,:,:]
          single_patch_norm = (single_patch.astype('float32')) / 255.
          single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
          single_patch_input = np.expand_dims(single_patch_norm, 0)
          single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8) #predict on single patch
          predicted_patches.append(single_patch_prediction)
predicted_patches = np.array(predicted_patches)
predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patch_size,patch_size) )
reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) #join patches to form whole img

stop = datetime.now()
print('Execution time: ',(stop-start)) #computation time

plt.subplot(121)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.imshow(test_img)
plt.subplot(122)
plt.title('Prediction')
plt.xticks([])
plt.yticks([])
plt.imshow(reconstructed_image,cmap='gray')

plt.show()
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_14 (InputLayer)          [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d_271 (Conv2D)            (None, 512, 512, 16  160         ['input_14[0][0]']
#                                 )
#
#  batch_normalization_271 (Batch  (None, 512, 512, 16  64         ['conv2d_271[0][0]']
#  Normalization)                 )
#
#  activation_271 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_271[0][0]']
#                                 )
#
#  dropout_117 (Dropout)          (None, 512, 512, 16  0           ['activation_271[0][0]']
#                                 )
#
#  conv2d_272 (Conv2D)            (None, 512, 512, 16  2320        ['dropout_117[0][0]']
#                                 )
#
#  batch_normalization_272 (Batch  (None, 512, 512, 16  64         ['conv2d_272[0][0]']
#  Normalization)                 )
#
#  activation_272 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_272[0][0]']
#                                 )
#
#  max_pooling2d_52 (MaxPooling2D  (None, 256, 256, 16  0          ['activation_272[0][0]']
#  )                              )
#
#  conv2d_273 (Conv2D)            (None, 256, 256, 32  4640        ['max_pooling2d_52[0][0]']
#                                 )
#
#  batch_normalization_273 (Batch  (None, 256, 256, 32  128        ['conv2d_273[0][0]']
#  Normalization)                 )
#
#  activation_273 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_273[0][0]']
#                                 )
#
#  conv2d_274 (Conv2D)            (None, 256, 256, 32  9248        ['activation_273[0][0]']
#                                 )
#
#  conv2d_275 (Conv2D)            (None, 256, 256, 32  544         ['max_pooling2d_52[0][0]']
#                                 )
#
#  batch_normalization_274 (Batch  (None, 256, 256, 32  128        ['conv2d_274[0][0]']
#  Normalization)                 )
#
#  batch_normalization_275 (Batch  (None, 256, 256, 32  128        ['conv2d_275[0][0]']
#  Normalization)                 )
#
#  activation_274 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_274[0][0]']
#                                 )
#
#  activation_275 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_275[0][0]']
#                                 )
#
#  dropout_118 (Dropout)          (None, 256, 256, 32  0           ['activation_274[0][0]']
#                                 )
#
#  add_24 (Add)                   (None, 256, 256, 32  0           ['activation_275[0][0]',
#                                 )                                 'dropout_118[0][0]']
#
#  max_pooling2d_53 (MaxPooling2D  (None, 128, 128, 32  0          ['add_24[0][0]']
#  )                              )
#
#  conv2d_276 (Conv2D)            (None, 128, 128, 64  18496       ['max_pooling2d_53[0][0]']
#                                 )
#
#  batch_normalization_276 (Batch  (None, 128, 128, 64  256        ['conv2d_276[0][0]']
#  Normalization)                 )
#
#  activation_276 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_276[0][0]']
#                                 )
#
#  conv2d_277 (Conv2D)            (None, 128, 128, 64  36928       ['activation_276[0][0]']
#                                 )
#
#  conv2d_278 (Conv2D)            (None, 128, 128, 64  2112        ['max_pooling2d_53[0][0]']
#                                 )
#
#  batch_normalization_277 (Batch  (None, 128, 128, 64  256        ['conv2d_277[0][0]']
#  Normalization)                 )
#
#  batch_normalization_278 (Batch  (None, 128, 128, 64  256        ['conv2d_278[0][0]']
#  Normalization)                 )
#
#  activation_277 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_277[0][0]']
#                                 )
#
#  activation_278 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_278[0][0]']
#                                 )
#
#  dropout_119 (Dropout)          (None, 128, 128, 64  0           ['activation_277[0][0]']
#                                 )
#
#  add_25 (Add)                   (None, 128, 128, 64  0           ['activation_278[0][0]',
#                                 )                                 'dropout_119[0][0]']
#
#  max_pooling2d_54 (MaxPooling2D  (None, 64, 64, 64)  0           ['add_25[0][0]']
#  )
#
#  conv2d_279 (Conv2D)            (None, 64, 64, 128)  73856       ['max_pooling2d_54[0][0]']
#
#  batch_normalization_279 (Batch  (None, 64, 64, 128)  512        ['conv2d_279[0][0]']
#  Normalization)
#
#  activation_279 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_279[0][0]']
#
#  conv2d_280 (Conv2D)            (None, 64, 64, 128)  147584      ['activation_279[0][0]']
#
#  conv2d_281 (Conv2D)            (None, 64, 64, 128)  8320        ['max_pooling2d_54[0][0]']
#
#  batch_normalization_280 (Batch  (None, 64, 64, 128)  512        ['conv2d_280[0][0]']
#  Normalization)
#
#  batch_normalization_281 (Batch  (None, 64, 64, 128)  512        ['conv2d_281[0][0]']
#  Normalization)
#
#  activation_280 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_280[0][0]']
#
#  activation_281 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_281[0][0]']
#
#  dropout_120 (Dropout)          (None, 64, 64, 128)  0           ['activation_280[0][0]']
#
#  add_26 (Add)                   (None, 64, 64, 128)  0           ['activation_281[0][0]',
#                                                                   'dropout_120[0][0]']
#
#  max_pooling2d_55 (MaxPooling2D  (None, 32, 32, 128)  0          ['add_26[0][0]']
#  )
#
#  conv2d_282 (Conv2D)            (None, 32, 32, 256)  295168      ['max_pooling2d_55[0][0]']
#
#  batch_normalization_282 (Batch  (None, 32, 32, 256)  1024       ['conv2d_282[0][0]']
#  Normalization)
#
#  activation_282 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_282[0][0]']
#
#  conv2d_283 (Conv2D)            (None, 32, 32, 256)  590080      ['activation_282[0][0]']
#
#  conv2d_284 (Conv2D)            (None, 32, 32, 256)  33024       ['max_pooling2d_55[0][0]']
#
#  batch_normalization_283 (Batch  (None, 32, 32, 256)  1024       ['conv2d_283[0][0]']
#  Normalization)
#
#  batch_normalization_284 (Batch  (None, 32, 32, 256)  1024       ['conv2d_284[0][0]']
#  Normalization)
#
#  activation_283 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_283[0][0]']
#
#  activation_284 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_284[0][0]']
#
#  dropout_121 (Dropout)          (None, 32, 32, 256)  0           ['activation_283[0][0]']
#
#  add_27 (Add)                   (None, 32, 32, 256)  0           ['activation_284[0][0]',
#                                                                   'dropout_121[0][0]']
#
#  up_sampling2d_52 (UpSampling2D  (None, 64, 64, 256)  0          ['add_27[0][0]']
#  )
#
#  concatenate_52 (Concatenate)   (None, 64, 64, 384)  0           ['up_sampling2d_52[0][0]',
#                                                                   'add_26[0][0]']
#
#  conv2d_285 (Conv2D)            (None, 64, 64, 128)  442496      ['concatenate_52[0][0]']
#
#  batch_normalization_285 (Batch  (None, 64, 64, 128)  512        ['conv2d_285[0][0]']
#  Normalization)
#
#  activation_285 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_285[0][0]']
#
#  conv2d_286 (Conv2D)            (None, 64, 64, 128)  147584      ['activation_285[0][0]']
#
#  conv2d_287 (Conv2D)            (None, 64, 64, 128)  49280       ['concatenate_52[0][0]']
#
#  batch_normalization_286 (Batch  (None, 64, 64, 128)  512        ['conv2d_286[0][0]']
#  Normalization)
#
#  batch_normalization_287 (Batch  (None, 64, 64, 128)  512        ['conv2d_287[0][0]']
#  Normalization)
#
#  activation_286 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_286[0][0]']
#
#  activation_287 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_287[0][0]']
#
#  dropout_122 (Dropout)          (None, 64, 64, 128)  0           ['activation_286[0][0]']
#
#  add_28 (Add)                   (None, 64, 64, 128)  0           ['activation_287[0][0]',
#                                                                   'dropout_122[0][0]']
#
#  up_sampling2d_53 (UpSampling2D  (None, 128, 128, 12  0          ['add_28[0][0]']
#  )                              8)
#
#  concatenate_53 (Concatenate)   (None, 128, 128, 19  0           ['up_sampling2d_53[0][0]',
#                                 2)                                'add_25[0][0]']
#
#  conv2d_288 (Conv2D)            (None, 128, 128, 64  110656      ['concatenate_53[0][0]']
#                                 )
#
#  batch_normalization_288 (Batch  (None, 128, 128, 64  256        ['conv2d_288[0][0]']
#  Normalization)                 )
#
#  activation_288 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_288[0][0]']
#                                 )
#
#  conv2d_289 (Conv2D)            (None, 128, 128, 64  36928       ['activation_288[0][0]']
#                                 )
#
#  conv2d_290 (Conv2D)            (None, 128, 128, 64  12352       ['concatenate_53[0][0]']
#                                 )
#
#  batch_normalization_289 (Batch  (None, 128, 128, 64  256        ['conv2d_289[0][0]']
#  Normalization)                 )
#
#  batch_normalization_290 (Batch  (None, 128, 128, 64  256        ['conv2d_290[0][0]']
#  Normalization)                 )
#
#  activation_289 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_289[0][0]']
#                                 )
#
#  activation_290 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_290[0][0]']
#                                 )
#
#  dropout_123 (Dropout)          (None, 128, 128, 64  0           ['activation_289[0][0]']
#                                 )
#
#  add_29 (Add)                   (None, 128, 128, 64  0           ['activation_290[0][0]',
#                                 )                                 'dropout_123[0][0]']
#
#  up_sampling2d_54 (UpSampling2D  (None, 256, 256, 64  0          ['add_29[0][0]']
#  )                              )
#
#  concatenate_54 (Concatenate)   (None, 256, 256, 96  0           ['up_sampling2d_54[0][0]',
#                                 )                                 'add_24[0][0]']
#
#  conv2d_291 (Conv2D)            (None, 256, 256, 32  27680       ['concatenate_54[0][0]']
#                                 )
#
#  batch_normalization_291 (Batch  (None, 256, 256, 32  128        ['conv2d_291[0][0]']
#  Normalization)                 )
#
#  activation_291 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_291[0][0]']
#                                 )
#
#  conv2d_292 (Conv2D)            (None, 256, 256, 32  9248        ['activation_291[0][0]']
#                                 )
#
#  conv2d_293 (Conv2D)            (None, 256, 256, 32  3104        ['concatenate_54[0][0]']
#                                 )
#
#  batch_normalization_292 (Batch  (None, 256, 256, 32  128        ['conv2d_292[0][0]']
#  Normalization)                 )
#
#  batch_normalization_293 (Batch  (None, 256, 256, 32  128        ['conv2d_293[0][0]']
#  Normalization)                 )
#
#  activation_292 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_292[0][0]']
#                                 )
#
#  activation_293 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_293[0][0]']
#                                 )
#
#  dropout_124 (Dropout)          (None, 256, 256, 32  0           ['activation_292[0][0]']
#                                 )
#
#  add_30 (Add)                   (None, 256, 256, 32  0           ['activation_293[0][0]',
#                                 )                                 'dropout_124[0][0]']
#
#  up_sampling2d_55 (UpSampling2D  (None, 512, 512, 32  0          ['add_30[0][0]']
#  )                              )
#
#  concatenate_55 (Concatenate)   (None, 512, 512, 48  0           ['up_sampling2d_55[0][0]',
#                                 )                                 'activation_272[0][0]']
#
#  conv2d_294 (Conv2D)            (None, 512, 512, 16  6928        ['concatenate_55[0][0]']
#                                 )
#
#  batch_normalization_294 (Batch  (None, 512, 512, 16  64         ['conv2d_294[0][0]']
#  Normalization)                 )
#
#  activation_294 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_294[0][0]']
#                                 )
#
#  conv2d_295 (Conv2D)            (None, 512, 512, 16  2320        ['activation_294[0][0]']
#                                 )
#
#  conv2d_296 (Conv2D)            (None, 512, 512, 16  784         ['concatenate_55[0][0]']
#                                 )
#
#  batch_normalization_295 (Batch  (None, 512, 512, 16  64         ['conv2d_295[0][0]']
#  Normalization)                 )
#
#  batch_normalization_296 (Batch  (None, 512, 512, 16  64         ['conv2d_296[0][0]']
#  Normalization)                 )
#
#  activation_295 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_295[0][0]']
#                                 )
#
#  activation_296 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_296[0][0]']
#                                 )
#
#  dropout_125 (Dropout)          (None, 512, 512, 16  0           ['activation_295[0][0]']
#                                 )
#
#  add_31 (Add)                   (None, 512, 512, 16  0           ['activation_296[0][0]',
#                                 )                                 'dropout_125[0][0]']
#
#  conv2d_297 (Conv2D)            (None, 512, 512, 1)  17          ['add_31[0][0]']
#
#  batch_normalization_297 (Batch  (None, 512, 512, 1)  4          ['conv2d_297[0][0]']
#  Normalization)
#
#  activation_297 (Activation)    (None, 512, 512, 1)  0           ['batch_normalization_297[0][0]']
#
# ==================================================================================================
# Total params: 2,080,629
# Trainable params: 2,076,243
# Non-trainable params: 4,386
# __________________________________________________________________________________________________
# WARNING:tensorflow:6 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fc3be93bd40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-fbfee0063ddd> in <module>
#      86       IoU = []
#      87       for label in labels:
# ---> 88           jaccard = jaccard_score(y_pred.flatten(),y_true.flatten(), pos_label=label, average='weighted')
#      89           IoU.append(jaccard)
#      90       IoU = np.mean(IoU) #jacard/IoU of single image
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in jaccard_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#     788     array([1. , 0. , 0.33...])
#     789     """
# --> 790     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#     791     samplewise = average == "samples"
#     792     MCM = multilabel_confusion_matrix(
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1346         raise ValueError("average has to be one of " + str(average_options))
#    1347
# -> 1348     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1349     # Convert to Python primitive type to avoid NumPy type / Python str
#    1350     # comparison. See https://github.com/numpy/numpy/issues/6784
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
# --> 334             % [int(l) for l in lengths]
#     335         )
#     336
#
# ValueError: Found input variables with inconsistent numbers of samples: [262144, 786432]

# %%
from datetime import datetime 
reconstructed_image = []
test_img = skimage.io.imread('/content/drive/MyDrive/training/images/cju0qkwl35piu0993l0dewei2.jpg') #test image

predicted_patches = []
start = datetime.now()   

test = test_img[:,:,1] #selecting green channel
test = clahe_equalized(test) #applying CLAHE
SIZE_X = (test_img.shape[1]//patch_size)*patch_size #getting size multiple of patch size
SIZE_Y = (test_img.shape[0]//patch_size)*patch_size #getting size multiple of patch size
test = cv2.resize(test, (SIZE_X, SIZE_Y))        
test = np.array(test)
patches = patchify(test, (patch_size, patch_size), step=patch_size) #create patches(patch_sizexpatch_sizex1)

for i in range(patches.shape[0]):
      for j in range(patches.shape[1]):
          single_patch = patches[i,j,:,:]
          single_patch_norm = (single_patch.astype('float32')) / 255.
          single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
          single_patch_input = np.expand_dims(single_patch_norm, 0)
          single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8) #predict on single patch
          predicted_patches.append(single_patch_prediction)
predicted_patches = np.array(predicted_patches)
predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patch_size,patch_size) )
reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) #join patches to form whole img

stop = datetime.now()
print('Execution time: ',(stop-start)) #computation time

plt.subplot(121)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.imshow(test_img)
plt.subplot(122)
plt.title('Prediction')
plt.xticks([])
plt.yticks([])
plt.imshow(reconstructed_image,cmap='gray')

plt.show()
# Out:
# Execution time:  0:00:00.068565

# %%
#checking segmentation results
import random
test_img_number = random.randint(0, len(testimg))
plt.figure(figsize=(20, 18))
plt.subplot(123)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.imshow(testimg[test_img_number])
plt.subplot(011)
plt.title('Ground Truth')
plt.xticks([])
plt.yticks([])
plt.imshow(ground_truth[test_img_number],cmap='gray')
plt.subplot(022)
plt.title('Prediction')
plt.xticks([])
plt.yticks([])
plt.imshow(prediction[test_img_number],cmap='gray')

plt.show()
