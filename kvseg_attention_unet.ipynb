# %%
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras import backend as K


#convolutional block
def conv_block(x, kernelsize, filters, dropout, batchnorm=False): 
    conv = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding="same")(x)
    if batchnorm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)
    conv = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding="same")(conv)
    if batchnorm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    return conv


#residual convolutional block
def res_conv_block(x, kernelsize, filters, dropout, batchnorm=False):
    conv1 = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding='same')(x)
    if batchnorm is True:
        conv1 = layers.BatchNormalization(axis=3)(conv1)
    conv1 = layers.Activation('relu')(conv1)    
    conv2 = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding='same')(conv1)
    if batchnorm is True:
        conv2 = layers.BatchNormalization(axis=3)(conv2)
        conv2 = layers.Activation("relu")(conv2)
    if dropout > 0:
        conv2 = layers.Dropout(dropout)(conv2)
        
    #skip connection    
    shortcut = layers.Conv2D(filters, kernel_size=(1, 1), kernel_initializer='he_normal', padding='same')(x)
    if batchnorm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)
    shortcut = layers.Activation("relu")(shortcut)
    respath = layers.add([shortcut, conv2])       
    return respath


#gating signal for attention unit
def gatingsignal(input, out_size, batchnorm=False):
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batchnorm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

#attention unit/block based on soft attention
def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), kernel_initializer='he_normal', padding='same')(x) 
    shape_theta_x = K.int_shape(theta_x)
    phi_g = layers.Conv2D(inter_shape, (1, 1), kernel_initializer='he_normal', padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3), strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]), kernel_initializer='he_normal', padding='same')(phi_g)
    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), kernel_initializer='he_normal', padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg) 
    upsample_psi = layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3), arguments={'repnum': shape_x[3]})(upsample_psi)                          
    y = layers.multiply([upsample_psi, x])
    result = layers.Conv2D(shape_x[3], (1, 1), kernel_initializer='he_normal', padding='same')(y)
    attenblock = layers.BatchNormalization()(result)
    return attenblock

#Simple U-NET
def unetmodel(input_shape, dropout=0.2, batchnorm=True):    
    
    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2
    
    inputs = layers.Input(input_shape)    

    # Downsampling layers
    dn_1 = conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    pool_1 = layers.MaxPooling2D(pool_size=(2,2))(dn_1)
    
    dn_2 = conv_block(pool_1, kernelsize, filters[1], dropout, batchnorm)
    pool_2 = layers.MaxPooling2D(pool_size=(2,2))(dn_2)
    
    dn_3 = conv_block(pool_2, kernelsize, filters[2], dropout, batchnorm)
    pool_3 = layers.MaxPooling2D(pool_size=(2,2))(dn_3)
    
    dn_4 = conv_block(pool_3, kernelsize, filters[3], dropout, batchnorm)
    pool_4 = layers.MaxPooling2D(pool_size=(2,2))(dn_4)
    
    dn_5 = conv_block(pool_4, kernelsize, filters[4], dropout, batchnorm)

    # Upsampling layers   
    up_5 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_5)
    up_5 = layers.concatenate([up_5, dn_4], axis=3)
    up_conv_5 = conv_block(up_5, kernelsize, filters[3], dropout, batchnorm)
    
    up_4 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_5)
    up_4 = layers.concatenate([up_4, dn_3], axis=3)
    up_conv_4 = conv_block(up_4, kernelsize, filters[2], dropout, batchnorm)
       
    up_3 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_4)
    up_3 = layers.concatenate([up_3, dn_2], axis=3)
    up_conv_3 = conv_block(up_3, kernelsize, filters[1], dropout, batchnorm)
    
    up_2 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_3)
    up_2 = layers.concatenate([up_2, dn_1], axis=3)
    up_conv_2 = conv_block(up_2, kernelsize, filters[0], dropout, batchnorm)    
   
    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv_2)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final)  

    model = models.Model(inputs=[inputs], outputs=[outputs])
    model.summary()        
    return model

    
#Attention U-NET
def attentionunet(input_shape, dropout=0.2, batchnorm=True):
    
    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2

    inputs = layers.Input(input_shape) 

    # Downsampling layers    
    dn_1 = conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    pool_1 = layers.MaxPooling2D(pool_size=(2,2))(dn_1)
    
    dn_2 = conv_block(pool_1, kernelsize, filters[1], dropout, batchnorm)
    pool_2 = layers.MaxPooling2D(pool_size=(2,2))(dn_2)
    
    dn_3 = conv_block(pool_2, kernelsize, filters[2], dropout, batchnorm)
    pool_3 = layers.MaxPooling2D(pool_size=(2,2))(dn_3)
    
    dn_4 = conv_block(pool_3, kernelsize, filters[3], dropout, batchnorm)
    pool_4 = layers.MaxPooling2D(pool_size=(2,2))(dn_4)
    
    dn_5 = conv_block(pool_4, kernelsize, filters[4], dropout, batchnorm)

    # Upsampling layers    
    gating_5 = gatingsignal(dn_5, filters[3], batchnorm)
    att_5 = attention_block(dn_4, gating_5, filters[3])
    up_5 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_5)
    up_5 = layers.concatenate([up_5, att_5], axis=3)
    up_conv_5 = conv_block(up_5, kernelsize, filters[3], dropout, batchnorm)
    
    gating_4 = gatingsignal(up_conv_5, filters[2], batchnorm)
    att_4 = attention_block(dn_3, gating_4, filters[2])
    up_4 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_5)
    up_4 = layers.concatenate([up_4, att_4], axis=3)
    up_conv_4 = conv_block(up_4, kernelsize, filters[2], dropout, batchnorm)
   
    gating_3 = gatingsignal(up_conv_4, filters[1], batchnorm)
    att_3 = attention_block(dn_2, gating_3, filters[1])
    up_3 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_4)
    up_3 = layers.concatenate([up_3, att_3], axis=3)
    up_conv_3 = conv_block(up_3, kernelsize, filters[1], dropout, batchnorm)
    
    gating_2 = gatingsignal(up_conv_3, filters[0], batchnorm)
    att_2 = attention_block(dn_1, gating_2, filters[0])
    up_2 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_3)
    up_2 = layers.concatenate([up_2, att_2], axis=3)
    up_conv_2 = conv_block(up_2, kernelsize, filters[0], dropout, batchnorm)
    
    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv_2)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final)  

    model = models.Model(inputs=[inputs], outputs=[outputs])
    model.summary()       
    return model    

#Res-UNET
def residualunet(input_shape, dropout=0.2, batchnorm=True):

    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2

    inputs = layers.Input(input_shape) 

    # Downsampling layers    
    dn_conv1 = conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    dn_pool1 = layers.MaxPooling2D(pool_size=(2,2))(dn_conv1)

    dn_conv2 = res_conv_block(dn_pool1, kernelsize, filters[1], dropout, batchnorm)
    dn_pool2 = layers.MaxPooling2D(pool_size=(2,2))(dn_conv2)

    dn_conv3 = res_conv_block(dn_pool2, kernelsize, filters[2], dropout, batchnorm)
    dn_pool3 = layers.MaxPooling2D(pool_size=(2,2))(dn_conv3)

    dn_conv4 = res_conv_block(dn_pool3, kernelsize, filters[3], dropout, batchnorm)
    dn_pool4 = layers.MaxPooling2D(pool_size=(2,2))(dn_conv4)

    dn_conv5 = res_conv_block(dn_pool4, kernelsize, filters[4], dropout, batchnorm)
   
    # upsampling layers
    up_conv6 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_conv5)
    up_conv6 = layers.concatenate([up_conv6, dn_conv4], axis=3)
    up_conv6 = res_conv_block(up_conv6, kernelsize, filters[3], dropout, batchnorm)

    up_conv7 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv6)
    up_conv7 = layers.concatenate([up_conv7, dn_conv3], axis=3)
    up_conv7 = res_conv_block(up_conv7, kernelsize, filters[2], dropout, batchnorm)

    up_conv8 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv7)
    up_conv8 = layers.concatenate([up_conv8, dn_conv2], axis=3)
    up_conv8 = res_conv_block(up_conv8, kernelsize, filters[1], dropout, batchnorm)

    up_conv9 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv8)
    up_conv9 = layers.concatenate([up_conv9, dn_conv1], axis=3)
    up_conv9 = res_conv_block(up_conv9, kernelsize, filters[0], dropout, batchnorm)


    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv9)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final) 
    
    model = models.Model(inputs=[inputs], outputs=[outputs])
    model.summary()
    return model

#Residual-Attention UNET (RA-UNET)
def residual_attentionunet(input_shape, dropout=0.2, batchnorm=True):
    
    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2
    
    inputs = layers.Input(input_shape)    
    
    # Downsampling layers
    dn_1 = res_conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    pool1 = layers.MaxPooling2D(pool_size=(2,2))(dn_1)

    dn_2 = res_conv_block(pool1, kernelsize, filters[1], dropout, batchnorm)
    pool2 = layers.MaxPooling2D(pool_size=(2,2))(dn_2)

    dn_3 = res_conv_block(pool2, kernelsize, filters[2], dropout, batchnorm)
    pool3 = layers.MaxPooling2D(pool_size=(2,2))(dn_3)

    dn_4 = res_conv_block(pool3, kernelsize, filters[3], dropout, batchnorm)
    pool4 = layers.MaxPooling2D(pool_size=(2,2))(dn_4)

    dn_5 = res_conv_block(pool4, kernelsize, filters[4], dropout, batchnorm)

    # Upsampling layers    
    gating_5 = gatingsignal(dn_5, filters[3], batchnorm)
    att_5 = attention_block(dn_4, gating_5, filters[3])
    up_5 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_5)
    up_5 = layers.concatenate([up_5, att_5], axis=3)
    up_conv_5 = res_conv_block(up_5, kernelsize, filters[3], dropout, batchnorm)
    
    gating_4 = gatingsignal(up_conv_5, filters[2], batchnorm)
    att_4 = attention_block(dn_3, gating_4, filters[2])
    up_4 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_5)
    up_4 = layers.concatenate([up_4, att_4], axis=3)
    up_conv_4 = res_conv_block(up_4, kernelsize, filters[2], dropout, batchnorm)
   
    gating_3 = gatingsignal(up_conv_4, filters[1], batchnorm)
    att_3 = attention_block(dn_2, gating_3, filters[1])
    up_3 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_4)
    up_3 = layers.concatenate([up_3, att_3], axis=3)
    up_conv_3 = res_conv_block(up_3, kernelsize, filters[1], dropout, batchnorm)
    
    gating_2 = gatingsignal(up_conv_3, filters[0], batchnorm)
    att_2 = attention_block(dn_1, gating_2, filters[0])
    up_2 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_3)
    up_2 = layers.concatenate([up_2, att_2], axis=3)
    up_conv_2 = res_conv_block(up_2, kernelsize, filters[0], dropout, batchnorm)
   
    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv_2)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final)  

    model = models.Model(inputs=[inputs], outputs=[outputs])
    model.summary() 
    return model

# %%
from tensorflow.keras import backend as K
from sklearn.metrics import jaccard_score,confusion_matrix


def IoU_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

def IoU_loss(y_true, y_pred):
    return -IoU_coef(y_true, y_pred)
 
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)
 
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)
  
def accuracy(y_true, y_pred):
    cm = confusion_matrix(y_true.flatten(),y_pred.flatten(), labels=[0, 1])
    acc = (cm[0,0]+cm[1,1])/(cm[0,0]+cm[0,1]+cm[1,0]+cm[1,1])
    return acc
  
def IoU(y_true, y_pred, labels = [0, 1]):
   IoU = []
   for label in labels:
      jaccard = jaccard_score(y_pred.flatten(),y_true.flatten(), pos_label=label, average='weighted')
      IoU.append(jaccard)     
   return np.mean(IoU)

# %%
# !pip install patchify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: patchify in /usr/local/lib/python3.7/dist-packages (0.2.3)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.7/dist-packages (from patchify) (1.21.6)

# %%
import os
import cv2
import numpy as np
import skimage.io
from matplotlib import pyplot as plt
from patchify import patchify
from PIL import Image
np.random.seed(0) 


#CLAHE
def clahe_equalized(imgs):    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))    
    imgs_equalized = clahe.apply(imgs)
    return imgs_equalized


path1 = '/content/drive/MyDrive/training/images' #training images directory
path2 = '/content/drive/MyDrive/training/masks' #training masks directory

image_dataset = []
mask_dataset = [] 

patch_size = 512

images = sorted(os.listdir(path1)) 

for i, image_name in enumerate(images):  
   if image_name.endswith(".jpg"):                   
       image = skimage.io.imread(path1+"/"+image_name)  #Read image
       
       image = image[:,:,1] #selecting green channel
       image = clahe_equalized(image) #applying CLAHE
       

       SIZE_X = (image.shape[1]//patch_size)*patch_size #getting size multiple of patch size
       SIZE_Y = (image.shape[0]//patch_size)*patch_size #getting size multiple of patch size
       image = Image.fromarray(image)        
       image = image.resize((512, 512)) #resize image       
       image = np.array(image) 
       patches_img = patchify(image, (patch_size, patch_size), step=patch_size)  #create patches(patch_sizexpatch_sizex1)
            
       for i in range(patches_img.shape[0]):
           for j in range(patches_img.shape[1]):                        
               single_patch_img = patches_img[i,j,:,:]                 
               single_patch_img = (single_patch_img.astype('float32')) / 255.                    
               image_dataset.append(single_patch_img)

masks = sorted(os.listdir(path2))  
for i, mask_name in enumerate(masks):  
    if mask_name.endswith(".jpg"):                  
        mask = skimage.io.imread(path2+"/"+mask_name,as_gray=True)   #Read masks
        
        
        SIZE_X = (mask.shape[1]//patch_size)*patch_size #getting size multiple of patch size
        SIZE_Y = (mask.shape[0]//patch_size)*patch_size #getting size multiple of patch size
        mask = Image.fromarray(mask)        
        mask = mask.resize((512, 512))  #resize image
        mask = np.array(mask)
        patches_mask = patchify(mask, (patch_size, patch_size), step=patch_size)  #create patches(patch_sizexpatch_sizex1)
            
        for i in range(patches_mask.shape[0]):
            for j in range(patches_mask.shape[1]):                            
                single_patch_mask = patches_mask[i,j,:,:]
                single_patch_mask = (single_patch_mask.astype('float32'))/255. 
                mask_dataset.append(single_patch_mask) 
 
image_dataset = np.array(image_dataset)
mask_dataset =  np.array(mask_dataset)
image_dataset = np.expand_dims(image_dataset,axis=-1)
mask_dataset =  np.expand_dims(mask_dataset,axis=-1)


#importing models

from tensorflow.keras.optimizers import Adam


IMG_HEIGHT = patch_size
IMG_WIDTH = patch_size
IMG_CHANNELS = 1
input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

#model = unetmodel(input_shape)
#model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])

#model = residualunet(input_shape)
#model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])
model = attentionunet(input_shape)
model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])
#model = residual_attentionunet(input_shape)
#model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])


#splitting data into 70-30 ratio to validate training performance
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size=0.2, random_state=0)

#train model
history = model.fit(x_train, y_train, 
                    verbose=1,
                    batch_size = 16,
                    validation_data=(x_test, y_test ), 
                    shuffle=False,
                    epochs=100)

#training-validation loss curve
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(7,5))
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'y', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

#training-validation accuracy curve
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(7,5))
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'y', label='Validation Accuracy')
plt.title('Training and validation accuracies')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

#training-validation IoU curve
iou_coef = history.history['IoU_coef']
val_iou_coef = history.history['val_IoU_coef']
plt.figure(figsize=(7,5))
plt.plot(epochs, iou_coef, 'r', label='Training IoU')
plt.plot(epochs, val_iou_coef, 'y', label='Validation IoU')
plt.title('Training and validation IoU coefficients')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

#save model
#model.save('/content/drive/MyDrive/training/retina_Unet_150epochs.hdf5')
# Out:
# Model: "model_14"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_15 (InputLayer)          [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d_298 (Conv2D)            (None, 512, 512, 16  160         ['input_15[0][0]']
#                                 )
#
#  batch_normalization_298 (Batch  (None, 512, 512, 16  64         ['conv2d_298[0][0]']
#  Normalization)                 )
#
#  activation_298 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_298[0][0]']
#                                 )
#
#  dropout_126 (Dropout)          (None, 512, 512, 16  0           ['activation_298[0][0]']
#                                 )
#
#  conv2d_299 (Conv2D)            (None, 512, 512, 16  2320        ['dropout_126[0][0]']
#                                 )
#
#  batch_normalization_299 (Batch  (None, 512, 512, 16  64         ['conv2d_299[0][0]']
#  Normalization)                 )
#
#  activation_299 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_299[0][0]']
#                                 )
#
#  max_pooling2d_56 (MaxPooling2D  (None, 256, 256, 16  0          ['activation_299[0][0]']
#  )                              )
#
#  conv2d_300 (Conv2D)            (None, 256, 256, 32  4640        ['max_pooling2d_56[0][0]']
#                                 )
#
#  batch_normalization_300 (Batch  (None, 256, 256, 32  128        ['conv2d_300[0][0]']
#  Normalization)                 )
#
#  activation_300 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_300[0][0]']
#                                 )
#
#  dropout_127 (Dropout)          (None, 256, 256, 32  0           ['activation_300[0][0]']
#                                 )
#
#  conv2d_301 (Conv2D)            (None, 256, 256, 32  9248        ['dropout_127[0][0]']
#                                 )
#
#  batch_normalization_301 (Batch  (None, 256, 256, 32  128        ['conv2d_301[0][0]']
#  Normalization)                 )
#
#  activation_301 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_301[0][0]']
#                                 )
#
#  max_pooling2d_57 (MaxPooling2D  (None, 128, 128, 32  0          ['activation_301[0][0]']
#  )                              )
#
#  conv2d_302 (Conv2D)            (None, 128, 128, 64  18496       ['max_pooling2d_57[0][0]']
#                                 )
#
#  batch_normalization_302 (Batch  (None, 128, 128, 64  256        ['conv2d_302[0][0]']
#  Normalization)                 )
#
#  activation_302 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_302[0][0]']
#                                 )
#
#  dropout_128 (Dropout)          (None, 128, 128, 64  0           ['activation_302[0][0]']
#                                 )
#
#  conv2d_303 (Conv2D)            (None, 128, 128, 64  36928       ['dropout_128[0][0]']
#                                 )
#
#  batch_normalization_303 (Batch  (None, 128, 128, 64  256        ['conv2d_303[0][0]']
#  Normalization)                 )
#
#  activation_303 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_303[0][0]']
#                                 )
#
#  max_pooling2d_58 (MaxPooling2D  (None, 64, 64, 64)  0           ['activation_303[0][0]']
#  )
#
#  conv2d_304 (Conv2D)            (None, 64, 64, 128)  73856       ['max_pooling2d_58[0][0]']
#
#  batch_normalization_304 (Batch  (None, 64, 64, 128)  512        ['conv2d_304[0][0]']
#  Normalization)
#
#  activation_304 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_304[0][0]']
#
#  dropout_129 (Dropout)          (None, 64, 64, 128)  0           ['activation_304[0][0]']
#
#  conv2d_305 (Conv2D)            (None, 64, 64, 128)  147584      ['dropout_129[0][0]']
#
#  batch_normalization_305 (Batch  (None, 64, 64, 128)  512        ['conv2d_305[0][0]']
#  Normalization)
#
#  activation_305 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_305[0][0]']
#
#  max_pooling2d_59 (MaxPooling2D  (None, 32, 32, 128)  0          ['activation_305[0][0]']
#  )
#
#  conv2d_306 (Conv2D)            (None, 32, 32, 256)  295168      ['max_pooling2d_59[0][0]']
#
#  batch_normalization_306 (Batch  (None, 32, 32, 256)  1024       ['conv2d_306[0][0]']
#  Normalization)
#
#  activation_306 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_306[0][0]']
#
#  dropout_130 (Dropout)          (None, 32, 32, 256)  0           ['activation_306[0][0]']
#
#  conv2d_307 (Conv2D)            (None, 32, 32, 256)  590080      ['dropout_130[0][0]']
#
#  batch_normalization_307 (Batch  (None, 32, 32, 256)  1024       ['conv2d_307[0][0]']
#  Normalization)
#
#  activation_307 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_307[0][0]']
#
#  conv2d_308 (Conv2D)            (None, 32, 32, 128)  32896       ['activation_307[0][0]']
#
#  batch_normalization_308 (Batch  (None, 32, 32, 128)  512        ['conv2d_308[0][0]']
#  Normalization)
#
#  activation_308 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_308[0][0]']
#
#  conv2d_310 (Conv2D)            (None, 32, 32, 128)  16512       ['activation_308[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 128)  147584     ['conv2d_310[0][0]']
#  ose)
#
#  conv2d_309 (Conv2D)            (None, 32, 32, 128)  65664       ['activation_305[0][0]']
#
#  add_32 (Add)                   (None, 32, 32, 128)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_309[0][0]']
#
#  activation_309 (Activation)    (None, 32, 32, 128)  0           ['add_32[0][0]']
#
#  conv2d_311 (Conv2D)            (None, 32, 32, 1)    129         ['activation_309[0][0]']
#
#  activation_310 (Activation)    (None, 32, 32, 1)    0           ['conv2d_311[0][0]']
#
#  up_sampling2d_56 (UpSampling2D  (None, 64, 64, 1)   0           ['activation_310[0][0]']
#  )
#
#  lambda (Lambda)                (None, 64, 64, 128)  0           ['up_sampling2d_56[0][0]']
#
#  multiply (Multiply)            (None, 64, 64, 128)  0           ['lambda[0][0]',
#                                                                   'activation_305[0][0]']
#
#  conv2d_312 (Conv2D)            (None, 64, 64, 128)  16512       ['multiply[0][0]']
#
#  up_sampling2d_57 (UpSampling2D  (None, 64, 64, 256)  0          ['activation_307[0][0]']
#  )
#
#  batch_normalization_309 (Batch  (None, 64, 64, 128)  512        ['conv2d_312[0][0]']
#  Normalization)
#
#  concatenate_56 (Concatenate)   (None, 64, 64, 384)  0           ['up_sampling2d_57[0][0]',
#                                                                   'batch_normalization_309[0][0]']
#
#  conv2d_313 (Conv2D)            (None, 64, 64, 128)  442496      ['concatenate_56[0][0]']
#
#  batch_normalization_310 (Batch  (None, 64, 64, 128)  512        ['conv2d_313[0][0]']
#  Normalization)
#
#  activation_311 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_310[0][0]']
#
#  dropout_131 (Dropout)          (None, 64, 64, 128)  0           ['activation_311[0][0]']
#
#  conv2d_314 (Conv2D)            (None, 64, 64, 128)  147584      ['dropout_131[0][0]']
#
#  batch_normalization_311 (Batch  (None, 64, 64, 128)  512        ['conv2d_314[0][0]']
#  Normalization)
#
#  activation_312 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_311[0][0]']
#
#  conv2d_315 (Conv2D)            (None, 64, 64, 64)   8256        ['activation_312[0][0]']
#
#  batch_normalization_312 (Batch  (None, 64, 64, 64)  256         ['conv2d_315[0][0]']
#  Normalization)
#
#  activation_313 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_312[0][0]']
#
#  conv2d_317 (Conv2D)            (None, 64, 64, 64)   4160        ['activation_313[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 64)  36928       ['conv2d_317[0][0]']
#  spose)
#
#  conv2d_316 (Conv2D)            (None, 64, 64, 64)   16448       ['activation_303[0][0]']
#
#  add_33 (Add)                   (None, 64, 64, 64)   0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_316[0][0]']
#
#  activation_314 (Activation)    (None, 64, 64, 64)   0           ['add_33[0][0]']
#
#  conv2d_318 (Conv2D)            (None, 64, 64, 1)    65          ['activation_314[0][0]']
#
#  activation_315 (Activation)    (None, 64, 64, 1)    0           ['conv2d_318[0][0]']
#
#  up_sampling2d_58 (UpSampling2D  (None, 128, 128, 1)  0          ['activation_315[0][0]']
#  )
#
#  lambda_1 (Lambda)              (None, 128, 128, 64  0           ['up_sampling2d_58[0][0]']
#                                 )
#
#  multiply_1 (Multiply)          (None, 128, 128, 64  0           ['lambda_1[0][0]',
#                                 )                                 'activation_303[0][0]']
#
#  conv2d_319 (Conv2D)            (None, 128, 128, 64  4160        ['multiply_1[0][0]']
#                                 )
#
#  up_sampling2d_59 (UpSampling2D  (None, 128, 128, 12  0          ['activation_312[0][0]']
#  )                              8)
#
#  batch_normalization_313 (Batch  (None, 128, 128, 64  256        ['conv2d_319[0][0]']
#  Normalization)                 )
#
#  concatenate_57 (Concatenate)   (None, 128, 128, 19  0           ['up_sampling2d_59[0][0]',
#                                 2)                                'batch_normalization_313[0][0]']
#
#  conv2d_320 (Conv2D)            (None, 128, 128, 64  110656      ['concatenate_57[0][0]']
#                                 )
#
#  batch_normalization_314 (Batch  (None, 128, 128, 64  256        ['conv2d_320[0][0]']
#  Normalization)                 )
#
#  activation_316 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_314[0][0]']
#                                 )
#
#  dropout_132 (Dropout)          (None, 128, 128, 64  0           ['activation_316[0][0]']
#                                 )
#
#  conv2d_321 (Conv2D)            (None, 128, 128, 64  36928       ['dropout_132[0][0]']
#                                 )
#
#  batch_normalization_315 (Batch  (None, 128, 128, 64  256        ['conv2d_321[0][0]']
#  Normalization)                 )
#
#  activation_317 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_315[0][0]']
#                                 )
#
#  conv2d_322 (Conv2D)            (None, 128, 128, 32  2080        ['activation_317[0][0]']
#                                 )
#
#  batch_normalization_316 (Batch  (None, 128, 128, 32  128        ['conv2d_322[0][0]']
#  Normalization)                 )
#
#  activation_318 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_316[0][0]']
#                                 )
#
#  conv2d_324 (Conv2D)            (None, 128, 128, 32  1056        ['activation_318[0][0]']
#                                 )
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 32  9248       ['conv2d_324[0][0]']
#  spose)                         )
#
#  conv2d_323 (Conv2D)            (None, 128, 128, 32  4128        ['activation_301[0][0]']
#                                 )
#
#  add_34 (Add)                   (None, 128, 128, 32  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'conv2d_323[0][0]']
#
#  activation_319 (Activation)    (None, 128, 128, 32  0           ['add_34[0][0]']
#                                 )
#
#  conv2d_325 (Conv2D)            (None, 128, 128, 1)  33          ['activation_319[0][0]']
#
#  activation_320 (Activation)    (None, 128, 128, 1)  0           ['conv2d_325[0][0]']
#
#  up_sampling2d_60 (UpSampling2D  (None, 256, 256, 1)  0          ['activation_320[0][0]']
#  )
#
#  lambda_2 (Lambda)              (None, 256, 256, 32  0           ['up_sampling2d_60[0][0]']
#                                 )
#
#  multiply_2 (Multiply)          (None, 256, 256, 32  0           ['lambda_2[0][0]',
#                                 )                                 'activation_301[0][0]']
#
#  conv2d_326 (Conv2D)            (None, 256, 256, 32  1056        ['multiply_2[0][0]']
#                                 )
#
#  up_sampling2d_61 (UpSampling2D  (None, 256, 256, 64  0          ['activation_317[0][0]']
#  )                              )
#
#  batch_normalization_317 (Batch  (None, 256, 256, 32  128        ['conv2d_326[0][0]']
#  Normalization)                 )
#
#  concatenate_58 (Concatenate)   (None, 256, 256, 96  0           ['up_sampling2d_61[0][0]',
#                                 )                                 'batch_normalization_317[0][0]']
#
#  conv2d_327 (Conv2D)            (None, 256, 256, 32  27680       ['concatenate_58[0][0]']
#                                 )
#
#  batch_normalization_318 (Batch  (None, 256, 256, 32  128        ['conv2d_327[0][0]']
#  Normalization)                 )
#
#  activation_321 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_318[0][0]']
#                                 )
#
#  dropout_133 (Dropout)          (None, 256, 256, 32  0           ['activation_321[0][0]']
#                                 )
#
#  conv2d_328 (Conv2D)            (None, 256, 256, 32  9248        ['dropout_133[0][0]']
#                                 )
#
#  batch_normalization_319 (Batch  (None, 256, 256, 32  128        ['conv2d_328[0][0]']
#  Normalization)                 )
#
#  activation_322 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_319[0][0]']
#                                 )
#
#  conv2d_329 (Conv2D)            (None, 256, 256, 16  528         ['activation_322[0][0]']
#                                 )
#
#  batch_normalization_320 (Batch  (None, 256, 256, 16  64         ['conv2d_329[0][0]']
#  Normalization)                 )
#
#  activation_323 (Activation)    (None, 256, 256, 16  0           ['batch_normalization_320[0][0]']
#                                 )
#
#  conv2d_331 (Conv2D)            (None, 256, 256, 16  272         ['activation_323[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 16  2320       ['conv2d_331[0][0]']
#  spose)                         )
#
#  conv2d_330 (Conv2D)            (None, 256, 256, 16  1040        ['activation_299[0][0]']
#                                 )
#
#  add_35 (Add)                   (None, 256, 256, 16  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_330[0][0]']
#
#  activation_324 (Activation)    (None, 256, 256, 16  0           ['add_35[0][0]']
#                                 )
#
#  conv2d_332 (Conv2D)            (None, 256, 256, 1)  17          ['activation_324[0][0]']
#
#  activation_325 (Activation)    (None, 256, 256, 1)  0           ['conv2d_332[0][0]']
#
#  up_sampling2d_62 (UpSampling2D  (None, 512, 512, 1)  0          ['activation_325[0][0]']
#  )
#
#  lambda_3 (Lambda)              (None, 512, 512, 16  0           ['up_sampling2d_62[0][0]']
#                                 )
#
#  multiply_3 (Multiply)          (None, 512, 512, 16  0           ['lambda_3[0][0]',
#                                 )                                 'activation_299[0][0]']
#
#  conv2d_333 (Conv2D)            (None, 512, 512, 16  272         ['multiply_3[0][0]']
#                                 )
#
#  up_sampling2d_63 (UpSampling2D  (None, 512, 512, 32  0          ['activation_322[0][0]']
#  )                              )
#
#  batch_normalization_321 (Batch  (None, 512, 512, 16  64         ['conv2d_333[0][0]']
#  Normalization)                 )
#
#  concatenate_59 (Concatenate)   (None, 512, 512, 48  0           ['up_sampling2d_63[0][0]',
#                                 )                                 'batch_normalization_321[0][0]']
#
#  conv2d_334 (Conv2D)            (None, 512, 512, 16  6928        ['concatenate_59[0][0]']
#                                 )
#
#  batch_normalization_322 (Batch  (None, 512, 512, 16  64         ['conv2d_334[0][0]']
#  Normalization)                 )
#
#  activation_326 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_322[0][0]']
#                                 )
#
#  dropout_134 (Dropout)          (None, 512, 512, 16  0           ['activation_326[0][0]']
#                                 )
#
#  conv2d_335 (Conv2D)            (None, 512, 512, 16  2320        ['dropout_134[0][0]']
#                                 )
#
#  batch_normalization_323 (Batch  (None, 512, 512, 16  64         ['conv2d_335[0][0]']
#  Normalization)                 )
#
#  activation_327 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_323[0][0]']
#                                 )
#
#  conv2d_336 (Conv2D)            (None, 512, 512, 1)  17          ['activation_327[0][0]']
#
#  batch_normalization_324 (Batch  (None, 512, 512, 1)  4          ['conv2d_336[0][0]']
#  Normalization)
#
#  activation_328 (Activation)    (None, 512, 512, 1)  0           ['batch_normalization_324[0][0]']
#
# ==================================================================================================
# Total params: 2,341,513
# Trainable params: 2,337,607
# Non-trainable params: 3,906
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/100
# 50/50 [==============================] - 33s 552ms/step - loss: -7.9576e-04 - accuracy: 0.5552 - IoU_coef: 7.9576e-04 - val_loss: -7.7310e-04 - val_accuracy: 0.7317 - val_IoU_coef: 7.7210e-04
# Epoch 2/100
# 50/50 [==============================] - 26s 528ms/step - loss: -8.9633e-04 - accuracy: 0.6015 - IoU_coef: 8.9633e-04 - val_loss: -9.1308e-04 - val_accuracy: 0.7105 - val_IoU_coef: 9.1104e-04
# Epoch 3/100
# 50/50 [==============================] - 26s 528ms/step - loss: -9.4834e-04 - accuracy: 0.6278 - IoU_coef: 9.4834e-04 - val_loss: -9.3497e-04 - val_accuracy: 0.6013 - val_IoU_coef: 9.3513e-04
# Epoch 4/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0010 - accuracy: 0.6565 - IoU_coef: 0.0010 - val_loss: -8.4829e-04 - val_accuracy: 0.7331 - val_IoU_coef: 8.5161e-04
# Epoch 5/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0011 - accuracy: 0.6822 - IoU_coef: 0.0011 - val_loss: -8.4932e-04 - val_accuracy: 0.7619 - val_IoU_coef: 8.5298e-04
# Epoch 6/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0011 - accuracy: 0.6956 - IoU_coef: 0.0011 - val_loss: -6.4292e-04 - val_accuracy: 0.8297 - val_IoU_coef: 6.4411e-04
# Epoch 7/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0012 - accuracy: 0.7089 - IoU_coef: 0.0012 - val_loss: -7.0455e-04 - val_accuracy: 0.8269 - val_IoU_coef: 7.0907e-04
# Epoch 8/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0012 - accuracy: 0.7243 - IoU_coef: 0.0012 - val_loss: -6.3974e-04 - val_accuracy: 0.8290 - val_IoU_coef: 6.4040e-04
# Epoch 9/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0013 - accuracy: 0.7303 - IoU_coef: 0.0013 - val_loss: -0.0010 - val_accuracy: 0.8119 - val_IoU_coef: 0.0010
# Epoch 10/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0013 - accuracy: 0.7412 - IoU_coef: 0.0013 - val_loss: -9.5143e-04 - val_accuracy: 0.8231 - val_IoU_coef: 9.5496e-04
# Epoch 11/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0014 - accuracy: 0.7543 - IoU_coef: 0.0014 - val_loss: -0.0011 - val_accuracy: 0.8177 - val_IoU_coef: 0.0011
# Epoch 12/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0014 - accuracy: 0.7623 - IoU_coef: 0.0014 - val_loss: -0.0012 - val_accuracy: 0.8188 - val_IoU_coef: 0.0012
# Epoch 13/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0015 - accuracy: 0.7654 - IoU_coef: 0.0015 - val_loss: -7.6079e-04 - val_accuracy: 0.8295 - val_IoU_coef: 7.6281e-04
# Epoch 14/100
# 50/50 [==============================] - 26s 526ms/step - loss: -0.0016 - accuracy: 0.7736 - IoU_coef: 0.0016 - val_loss: -0.0015 - val_accuracy: 0.8146 - val_IoU_coef: 0.0015
# Epoch 15/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0016 - accuracy: 0.7800 - IoU_coef: 0.0016 - val_loss: -0.0015 - val_accuracy: 0.8088 - val_IoU_coef: 0.0016
# Epoch 16/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0017 - accuracy: 0.7865 - IoU_coef: 0.0017 - val_loss: -0.0015 - val_accuracy: 0.8166 - val_IoU_coef: 0.0015
# Epoch 17/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0018 - accuracy: 0.7914 - IoU_coef: 0.0018 - val_loss: -0.0013 - val_accuracy: 0.8258 - val_IoU_coef: 0.0013
# Epoch 18/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0019 - accuracy: 0.7951 - IoU_coef: 0.0019 - val_loss: -0.0012 - val_accuracy: 0.8282 - val_IoU_coef: 0.0013
# Epoch 19/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0019 - accuracy: 0.7980 - IoU_coef: 0.0019 - val_loss: -0.0018 - val_accuracy: 0.7905 - val_IoU_coef: 0.0018
# Epoch 20/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0020 - accuracy: 0.8001 - IoU_coef: 0.0020 - val_loss: -0.0019 - val_accuracy: 0.8047 - val_IoU_coef: 0.0019
# Epoch 21/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0020 - accuracy: 0.8020 - IoU_coef: 0.0020 - val_loss: -0.0018 - val_accuracy: 0.8179 - val_IoU_coef: 0.0018
# Epoch 22/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0021 - accuracy: 0.8070 - IoU_coef: 0.0021 - val_loss: -0.0017 - val_accuracy: 0.8278 - val_IoU_coef: 0.0017
# Epoch 23/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0022 - accuracy: 0.8091 - IoU_coef: 0.0022 - val_loss: -0.0020 - val_accuracy: 0.8254 - val_IoU_coef: 0.0020
# Epoch 24/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0023 - accuracy: 0.8112 - IoU_coef: 0.0023 - val_loss: -0.0013 - val_accuracy: 0.8292 - val_IoU_coef: 0.0013
# Epoch 25/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0023 - accuracy: 0.8130 - IoU_coef: 0.0023 - val_loss: -0.0019 - val_accuracy: 0.8266 - val_IoU_coef: 0.0019
# Epoch 26/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0024 - accuracy: 0.8131 - IoU_coef: 0.0024 - val_loss: -0.0013 - val_accuracy: 0.8300 - val_IoU_coef: 0.0013
# Epoch 27/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0024 - accuracy: 0.8150 - IoU_coef: 0.0024 - val_loss: -0.0019 - val_accuracy: 0.8272 - val_IoU_coef: 0.0019
# Epoch 28/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0025 - accuracy: 0.8164 - IoU_coef: 0.0025 - val_loss: -0.0017 - val_accuracy: 0.8297 - val_IoU_coef: 0.0017
# Epoch 29/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0026 - accuracy: 0.8184 - IoU_coef: 0.0026 - val_loss: -0.0017 - val_accuracy: 0.8294 - val_IoU_coef: 0.0017
# Epoch 30/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0026 - accuracy: 0.8199 - IoU_coef: 0.0026 - val_loss: -0.0023 - val_accuracy: 0.8285 - val_IoU_coef: 0.0023
# Epoch 31/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0027 - accuracy: 0.8206 - IoU_coef: 0.0027 - val_loss: -0.0022 - val_accuracy: 0.8278 - val_IoU_coef: 0.0022
# Epoch 32/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0027 - accuracy: 0.8205 - IoU_coef: 0.0027 - val_loss: -0.0021 - val_accuracy: 0.8286 - val_IoU_coef: 0.0021
# Epoch 33/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0028 - accuracy: 0.8220 - IoU_coef: 0.0028 - val_loss: -0.0025 - val_accuracy: 0.8201 - val_IoU_coef: 0.0025
# Epoch 34/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0028 - accuracy: 0.8226 - IoU_coef: 0.0028 - val_loss: -0.0023 - val_accuracy: 0.8271 - val_IoU_coef: 0.0023
# Epoch 35/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0029 - accuracy: 0.8229 - IoU_coef: 0.0029 - val_loss: -0.0014 - val_accuracy: 0.8299 - val_IoU_coef: 0.0014
# Epoch 36/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0029 - accuracy: 0.8238 - IoU_coef: 0.0029 - val_loss: -0.0024 - val_accuracy: 0.8230 - val_IoU_coef: 0.0024
# Epoch 37/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0030 - accuracy: 0.8241 - IoU_coef: 0.0030 - val_loss: -0.0026 - val_accuracy: 0.8248 - val_IoU_coef: 0.0026
# Epoch 38/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0030 - accuracy: 0.8255 - IoU_coef: 0.0030 - val_loss: -0.0028 - val_accuracy: 0.8195 - val_IoU_coef: 0.0028
# Epoch 39/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0030 - accuracy: 0.8254 - IoU_coef: 0.0030 - val_loss: -0.0028 - val_accuracy: 0.8250 - val_IoU_coef: 0.0028
# Epoch 40/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0031 - accuracy: 0.8260 - IoU_coef: 0.0031 - val_loss: -0.0028 - val_accuracy: 0.8271 - val_IoU_coef: 0.0028
# Epoch 41/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0031 - accuracy: 0.8261 - IoU_coef: 0.0031 - val_loss: -0.0029 - val_accuracy: 0.8168 - val_IoU_coef: 0.0029
# Epoch 42/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0032 - accuracy: 0.8268 - IoU_coef: 0.0032 - val_loss: -0.0030 - val_accuracy: 0.8252 - val_IoU_coef: 0.0030
# Epoch 43/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0032 - accuracy: 0.8268 - IoU_coef: 0.0032 - val_loss: -0.0030 - val_accuracy: 0.8196 - val_IoU_coef: 0.0030
# Epoch 44/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0032 - accuracy: 0.8272 - IoU_coef: 0.0032 - val_loss: -0.0030 - val_accuracy: 0.8234 - val_IoU_coef: 0.0030
# Epoch 45/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0032 - accuracy: 0.8269 - IoU_coef: 0.0032 - val_loss: -0.0030 - val_accuracy: 0.8207 - val_IoU_coef: 0.0030
# Epoch 46/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0033 - accuracy: 0.8274 - IoU_coef: 0.0033 - val_loss: -0.0031 - val_accuracy: 0.8233 - val_IoU_coef: 0.0031
# Epoch 47/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0033 - accuracy: 0.8274 - IoU_coef: 0.0033 - val_loss: -0.0031 - val_accuracy: 0.8267 - val_IoU_coef: 0.0031
# Epoch 48/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0033 - accuracy: 0.8280 - IoU_coef: 0.0033 - val_loss: -0.0030 - val_accuracy: 0.8285 - val_IoU_coef: 0.0031
# Epoch 49/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0034 - accuracy: 0.8283 - IoU_coef: 0.0034 - val_loss: -0.0027 - val_accuracy: 0.8300 - val_IoU_coef: 0.0027
# Epoch 50/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0034 - accuracy: 0.8279 - IoU_coef: 0.0034 - val_loss: -0.0031 - val_accuracy: 0.8225 - val_IoU_coef: 0.0031
# Epoch 51/100
# 50/50 [==============================] - 26s 526ms/step - loss: -0.0034 - accuracy: 0.8285 - IoU_coef: 0.0034 - val_loss: -0.0032 - val_accuracy: 0.8255 - val_IoU_coef: 0.0032
# Epoch 52/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0034 - accuracy: 0.8287 - IoU_coef: 0.0034 - val_loss: -0.0032 - val_accuracy: 0.8259 - val_IoU_coef: 0.0032
# Epoch 53/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0034 - accuracy: 0.8289 - IoU_coef: 0.0034 - val_loss: -0.0030 - val_accuracy: 0.8296 - val_IoU_coef: 0.0030
# Epoch 54/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0035 - accuracy: 0.8290 - IoU_coef: 0.0035 - val_loss: -0.0032 - val_accuracy: 0.8282 - val_IoU_coef: 0.0032
# Epoch 55/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0035 - accuracy: 0.8289 - IoU_coef: 0.0035 - val_loss: -0.0032 - val_accuracy: 0.8236 - val_IoU_coef: 0.0032
# Epoch 56/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0035 - accuracy: 0.8287 - IoU_coef: 0.0035 - val_loss: -0.0033 - val_accuracy: 0.8267 - val_IoU_coef: 0.0033
# Epoch 57/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0035 - accuracy: 0.8292 - IoU_coef: 0.0035 - val_loss: -0.0032 - val_accuracy: 0.8258 - val_IoU_coef: 0.0032
# Epoch 58/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0035 - accuracy: 0.8294 - IoU_coef: 0.0035 - val_loss: -0.0032 - val_accuracy: 0.8225 - val_IoU_coef: 0.0032
# Epoch 59/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0036 - accuracy: 0.8294 - IoU_coef: 0.0036 - val_loss: -0.0033 - val_accuracy: 0.8271 - val_IoU_coef: 0.0033
# Epoch 60/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0036 - accuracy: 0.8295 - IoU_coef: 0.0036 - val_loss: -0.0034 - val_accuracy: 0.8286 - val_IoU_coef: 0.0034
# Epoch 61/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0036 - accuracy: 0.8296 - IoU_coef: 0.0036 - val_loss: -0.0033 - val_accuracy: 0.8252 - val_IoU_coef: 0.0033
# Epoch 62/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0036 - accuracy: 0.8298 - IoU_coef: 0.0036 - val_loss: -0.0034 - val_accuracy: 0.8272 - val_IoU_coef: 0.0034
# Epoch 63/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0036 - accuracy: 0.8298 - IoU_coef: 0.0036 - val_loss: -0.0033 - val_accuracy: 0.8279 - val_IoU_coef: 0.0033
# Epoch 64/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0036 - accuracy: 0.8297 - IoU_coef: 0.0036 - val_loss: -0.0033 - val_accuracy: 0.8226 - val_IoU_coef: 0.0033
# Epoch 65/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0036 - accuracy: 0.8296 - IoU_coef: 0.0036 - val_loss: -0.0034 - val_accuracy: 0.8246 - val_IoU_coef: 0.0034
# Epoch 66/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0036 - accuracy: 0.8297 - IoU_coef: 0.0036 - val_loss: -0.0033 - val_accuracy: 0.8266 - val_IoU_coef: 0.0033
# Epoch 67/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0036 - accuracy: 0.8297 - IoU_coef: 0.0036 - val_loss: -0.0034 - val_accuracy: 0.8245 - val_IoU_coef: 0.0034
# Epoch 68/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0036 - accuracy: 0.8295 - IoU_coef: 0.0036 - val_loss: -0.0032 - val_accuracy: 0.8277 - val_IoU_coef: 0.0032
# Epoch 69/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0036 - accuracy: 0.8288 - IoU_coef: 0.0036 - val_loss: -0.0029 - val_accuracy: 0.8143 - val_IoU_coef: 0.0030
# Epoch 70/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0036 - accuracy: 0.8296 - IoU_coef: 0.0036 - val_loss: -0.0034 - val_accuracy: 0.8257 - val_IoU_coef: 0.0034
# Epoch 71/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0037 - accuracy: 0.8298 - IoU_coef: 0.0037 - val_loss: -0.0034 - val_accuracy: 0.8244 - val_IoU_coef: 0.0034
# Epoch 72/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0037 - accuracy: 0.8297 - IoU_coef: 0.0037 - val_loss: -0.0034 - val_accuracy: 0.8274 - val_IoU_coef: 0.0034
# Epoch 73/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0037 - accuracy: 0.8299 - IoU_coef: 0.0037 - val_loss: -0.0035 - val_accuracy: 0.8281 - val_IoU_coef: 0.0035
# Epoch 74/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0037 - accuracy: 0.8300 - IoU_coef: 0.0037 - val_loss: -0.0035 - val_accuracy: 0.8266 - val_IoU_coef: 0.0035
# Epoch 75/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0037 - accuracy: 0.8295 - IoU_coef: 0.0037 - val_loss: -0.0035 - val_accuracy: 0.8274 - val_IoU_coef: 0.0035
# Epoch 76/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0037 - accuracy: 0.8299 - IoU_coef: 0.0037 - val_loss: -0.0035 - val_accuracy: 0.8264 - val_IoU_coef: 0.0035
# Epoch 77/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0037 - accuracy: 0.8299 - IoU_coef: 0.0037 - val_loss: -0.0033 - val_accuracy: 0.8188 - val_IoU_coef: 0.0033
# Epoch 78/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0037 - accuracy: 0.8299 - IoU_coef: 0.0037 - val_loss: -0.0034 - val_accuracy: 0.8261 - val_IoU_coef: 0.0034
# Epoch 79/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0037 - accuracy: 0.8298 - IoU_coef: 0.0037 - val_loss: -0.0034 - val_accuracy: 0.8268 - val_IoU_coef: 0.0034
# Epoch 80/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0037 - accuracy: 0.8299 - IoU_coef: 0.0037 - val_loss: -0.0035 - val_accuracy: 0.8269 - val_IoU_coef: 0.0035
# Epoch 81/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0037 - accuracy: 0.8301 - IoU_coef: 0.0037 - val_loss: -0.0034 - val_accuracy: 0.8250 - val_IoU_coef: 0.0035
# Epoch 82/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0037 - accuracy: 0.8301 - IoU_coef: 0.0037 - val_loss: -0.0035 - val_accuracy: 0.8249 - val_IoU_coef: 0.0035
# Epoch 83/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0037 - accuracy: 0.8301 - IoU_coef: 0.0037 - val_loss: -0.0035 - val_accuracy: 0.8268 - val_IoU_coef: 0.0035
# Epoch 84/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8219 - val_IoU_coef: 0.0034
# Epoch 85/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0038 - accuracy: 0.8301 - IoU_coef: 0.0038 - val_loss: -0.0033 - val_accuracy: 0.8290 - val_IoU_coef: 0.0033
# Epoch 86/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0038 - accuracy: 0.8301 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8242 - val_IoU_coef: 0.0035
# Epoch 87/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0036 - val_accuracy: 0.8287 - val_IoU_coef: 0.0036
# Epoch 88/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8188 - val_IoU_coef: 0.0034
# Epoch 89/100
# 50/50 [==============================] - 26s 528ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8231 - val_IoU_coef: 0.0035
# Epoch 90/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0038 - accuracy: 0.8301 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8211 - val_IoU_coef: 0.0034
# Epoch 91/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0036 - val_accuracy: 0.8270 - val_IoU_coef: 0.0036
# Epoch 92/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0036 - val_accuracy: 0.8292 - val_IoU_coef: 0.0036
# Epoch 93/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0038 - accuracy: 0.8301 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8274 - val_IoU_coef: 0.0035
# Epoch 94/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0036 - val_accuracy: 0.8273 - val_IoU_coef: 0.0036
# Epoch 95/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0036 - val_accuracy: 0.8253 - val_IoU_coef: 0.0036
# Epoch 96/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0036 - val_accuracy: 0.8270 - val_IoU_coef: 0.0036
# Epoch 97/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8242 - val_IoU_coef: 0.0035
# Epoch 98/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0036 - val_accuracy: 0.8256 - val_IoU_coef: 0.0036
# Epoch 99/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0036 - val_accuracy: 0.8278 - val_IoU_coef: 0.0036
# Epoch 100/100
# 50/50 [==============================] - 26s 527ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0036 - val_accuracy: 0.8254 - val_IoU_coef: 0.0036

# %%
model.save('attunet.h5')

# %%
import os
import cv2
import numpy as np
import skimage.io
from matplotlib import pyplot as plt
from patchify import patchify, unpatchify
np.random.seed(0)

# CLAHE
def clahe_equalized(imgs):    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))    
    imgs_equalized = clahe.apply(imgs)
    return imgs_equalized

patch_size = 512

#loading model architectures

from tensorflow.keras.optimizers import Adam


IMG_HEIGHT = patch_size
IMG_WIDTH = patch_size
IMG_CHANNELS = 1

input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

model = attentionunet(input_shape) #/residualunet(input_shape)/attentionunet(input_shape)/attention_residualunet(input_shape) 
model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])
model.load_weights('/content/attunet.h5') #loading weights


path1 = '/content/drive/MyDrive/training/images/'    #test dataset images directory path
path2 = '/content/drive/MyDrive/training/masks/'     #test dataset mask directory path


from sklearn.metrics import jaccard_score,confusion_matrix

testimg = []
ground_truth = []
prediction = []
global_IoU = []
global_accuracy = []

testimages = sorted(os.listdir(path1))
testmasks =  sorted(os.listdir(path2))

for idx, image_name in enumerate(testimages):  
   if image_name.endswith(".jpg"):  
      predicted_patches = []
      test_img = skimage.io.imread(path1+"/"+image_name)
     
      test = test_img[:,:,1] #selecting green channel
      test = clahe_equalized(test) #applying CLAHE
      SIZE_X = (test_img.shape[1]//patch_size)*patch_size #getting size multiple of patch size
      SIZE_Y = (test_img.shape[0]//patch_size)*patch_size #getting size multiple of patch size
      test = cv2.resize(test, (SIZE_X, SIZE_Y))
      testimg.append(test)           
      test = np.array(test)

      patches = patchify(test, (patch_size, patch_size), step=patch_size) #create patches(patch_sizexpatch_sizex1)

      for i in range(patches.shape[0]):
                for j in range(patches.shape[1]):
                  single_patch = patches[i,j,:,:]
                  single_patch_norm = (single_patch.astype('float32')) / 255.
                  single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
                  single_patch_input = np.expand_dims(single_patch_norm, 0)
                  single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8) #predict on single patch
                  predicted_patches.append(single_patch_prediction)
      predicted_patches = np.array(predicted_patches)
      predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patch_size,patch_size) )
      reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) #join patches to form whole img
      prediction.append(reconstructed_image) 

      groundtruth=[]
      groundtruth = skimage.io.imread(path2+'/'+testmasks[idx]) #reading mask of the test img      
      SIZE_X = (groundtruth.shape[1]//patch_size)*patch_size 
      SIZE_Y = (groundtruth.shape[0]//patch_size)*patch_size  
      groundtruth = cv2.resize(groundtruth, (SIZE_X, SIZE_Y))  
      ground_truth.append(groundtruth)

      y_true = groundtruth
      y_pred = reconstructed_image
      labels = [0, 1]
      IoU = []
      for label in labels:
          jaccard = jaccard_score(y_pred.flatten(),y_true.flatten(), pos_label=label, average='weighted')
          IoU.append(jaccard)
      IoU = np.mean(IoU) #jacard/IoU of single image
      global_IoU.append(IoU)

      cm=[]
      accuracy = []
      cm = confusion_matrix(y_true.flatten(),y_pred.flatten(), labels=[0, 1])
      accuracy = (cm[0,0]+cm[1,1])/(cm[0,0]+cm[0,1]+cm[1,0]+cm[1,1]) #accuracy of single image
      global_accuracy.append(accuracy)


avg_acc =  np.mean(global_accuracy)
mean_IoU = np.mean(global_IoU)

print('Average accuracy is',avg_acc)
print('mean IoU is',mean_IoU)






#prediction on single image
from datetime import datetime 
reconstructed_image = []
test_img = skimage.io.imread('/content/drive/MyDrive/DRIVE/test/images/01_test.tif') #test image

predicted_patches = []
start = datetime.now()   

test = test_img[:,:,1] #selecting green channel
test = clahe_equalized(test) #applying CLAHE
SIZE_X = (test_img.shape[1]//patch_size)*patch_size #getting size multiple of patch size
SIZE_Y = (test_img.shape[0]//patch_size)*patch_size #getting size multiple of patch size
test = cv2.resize(test, (SIZE_X, SIZE_Y))        
test = np.array(test)
patches = patchify(test, (patch_size, patch_size), step=patch_size) #create patches(patch_sizexpatch_sizex1)

for i in range(patches.shape[0]):
      for j in range(patches.shape[1]):
          single_patch = patches[i,j,:,:]
          single_patch_norm = (single_patch.astype('float32')) / 255.
          single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
          single_patch_input = np.expand_dims(single_patch_norm, 0)
          single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8) #predict on single patch
          predicted_patches.append(single_patch_prediction)
predicted_patches = np.array(predicted_patches)
predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patch_size,patch_size) )
reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) #join patches to form whole img

stop = datetime.now()
print('Execution time: ',(stop-start)) #computation time

plt.subplot(121)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.imshow(test_img)
plt.subplot(122)
plt.title('Prediction')
plt.xticks([])
plt.yticks([])
plt.imshow(reconstructed_image,cmap='gray')

plt.show()
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_16 (InputLayer)          [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d_337 (Conv2D)            (None, 512, 512, 16  160         ['input_16[0][0]']
#                                 )
#
#  batch_normalization_325 (Batch  (None, 512, 512, 16  64         ['conv2d_337[0][0]']
#  Normalization)                 )
#
#  activation_329 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_325[0][0]']
#                                 )
#
#  dropout_135 (Dropout)          (None, 512, 512, 16  0           ['activation_329[0][0]']
#                                 )
#
#  conv2d_338 (Conv2D)            (None, 512, 512, 16  2320        ['dropout_135[0][0]']
#                                 )
#
#  batch_normalization_326 (Batch  (None, 512, 512, 16  64         ['conv2d_338[0][0]']
#  Normalization)                 )
#
#  activation_330 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_326[0][0]']
#                                 )
#
#  max_pooling2d_60 (MaxPooling2D  (None, 256, 256, 16  0          ['activation_330[0][0]']
#  )                              )
#
#  conv2d_339 (Conv2D)            (None, 256, 256, 32  4640        ['max_pooling2d_60[0][0]']
#                                 )
#
#  batch_normalization_327 (Batch  (None, 256, 256, 32  128        ['conv2d_339[0][0]']
#  Normalization)                 )
#
#  activation_331 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_327[0][0]']
#                                 )
#
#  dropout_136 (Dropout)          (None, 256, 256, 32  0           ['activation_331[0][0]']
#                                 )
#
#  conv2d_340 (Conv2D)            (None, 256, 256, 32  9248        ['dropout_136[0][0]']
#                                 )
#
#  batch_normalization_328 (Batch  (None, 256, 256, 32  128        ['conv2d_340[0][0]']
#  Normalization)                 )
#
#  activation_332 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_328[0][0]']
#                                 )
#
#  max_pooling2d_61 (MaxPooling2D  (None, 128, 128, 32  0          ['activation_332[0][0]']
#  )                              )
#
#  conv2d_341 (Conv2D)            (None, 128, 128, 64  18496       ['max_pooling2d_61[0][0]']
#                                 )
#
#  batch_normalization_329 (Batch  (None, 128, 128, 64  256        ['conv2d_341[0][0]']
#  Normalization)                 )
#
#  activation_333 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_329[0][0]']
#                                 )
#
#  dropout_137 (Dropout)          (None, 128, 128, 64  0           ['activation_333[0][0]']
#                                 )
#
#  conv2d_342 (Conv2D)            (None, 128, 128, 64  36928       ['dropout_137[0][0]']
#                                 )
#
#  batch_normalization_330 (Batch  (None, 128, 128, 64  256        ['conv2d_342[0][0]']
#  Normalization)                 )
#
#  activation_334 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_330[0][0]']
#                                 )
#
#  max_pooling2d_62 (MaxPooling2D  (None, 64, 64, 64)  0           ['activation_334[0][0]']
#  )
#
#  conv2d_343 (Conv2D)            (None, 64, 64, 128)  73856       ['max_pooling2d_62[0][0]']
#
#  batch_normalization_331 (Batch  (None, 64, 64, 128)  512        ['conv2d_343[0][0]']
#  Normalization)
#
#  activation_335 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_331[0][0]']
#
#  dropout_138 (Dropout)          (None, 64, 64, 128)  0           ['activation_335[0][0]']
#
#  conv2d_344 (Conv2D)            (None, 64, 64, 128)  147584      ['dropout_138[0][0]']
#
#  batch_normalization_332 (Batch  (None, 64, 64, 128)  512        ['conv2d_344[0][0]']
#  Normalization)
#
#  activation_336 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_332[0][0]']
#
#  max_pooling2d_63 (MaxPooling2D  (None, 32, 32, 128)  0          ['activation_336[0][0]']
#  )
#
#  conv2d_345 (Conv2D)            (None, 32, 32, 256)  295168      ['max_pooling2d_63[0][0]']
#
#  batch_normalization_333 (Batch  (None, 32, 32, 256)  1024       ['conv2d_345[0][0]']
#  Normalization)
#
#  activation_337 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_333[0][0]']
#
#  dropout_139 (Dropout)          (None, 32, 32, 256)  0           ['activation_337[0][0]']
#
#  conv2d_346 (Conv2D)            (None, 32, 32, 256)  590080      ['dropout_139[0][0]']
#
#  batch_normalization_334 (Batch  (None, 32, 32, 256)  1024       ['conv2d_346[0][0]']
#  Normalization)
#
#  activation_338 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_334[0][0]']
#
#  conv2d_347 (Conv2D)            (None, 32, 32, 128)  32896       ['activation_338[0][0]']
#
#  batch_normalization_335 (Batch  (None, 32, 32, 128)  512        ['conv2d_347[0][0]']
#  Normalization)
#
#  activation_339 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_335[0][0]']
#
#  conv2d_349 (Conv2D)            (None, 32, 32, 128)  16512       ['activation_339[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 32, 32, 128)  147584     ['conv2d_349[0][0]']
#  spose)
#
#  conv2d_348 (Conv2D)            (None, 32, 32, 128)  65664       ['activation_336[0][0]']
#
#  add_36 (Add)                   (None, 32, 32, 128)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'conv2d_348[0][0]']
#
#  activation_340 (Activation)    (None, 32, 32, 128)  0           ['add_36[0][0]']
#
#  conv2d_350 (Conv2D)            (None, 32, 32, 1)    129         ['activation_340[0][0]']
#
#  activation_341 (Activation)    (None, 32, 32, 1)    0           ['conv2d_350[0][0]']
#
#  up_sampling2d_64 (UpSampling2D  (None, 64, 64, 1)   0           ['activation_341[0][0]']
#  )
#
#  lambda_4 (Lambda)              (None, 64, 64, 128)  0           ['up_sampling2d_64[0][0]']
#
#  multiply_4 (Multiply)          (None, 64, 64, 128)  0           ['lambda_4[0][0]',
#                                                                   'activation_336[0][0]']
#
#  conv2d_351 (Conv2D)            (None, 64, 64, 128)  16512       ['multiply_4[0][0]']
#
#  up_sampling2d_65 (UpSampling2D  (None, 64, 64, 256)  0          ['activation_338[0][0]']
#  )
#
#  batch_normalization_336 (Batch  (None, 64, 64, 128)  512        ['conv2d_351[0][0]']
#  Normalization)
#
#  concatenate_60 (Concatenate)   (None, 64, 64, 384)  0           ['up_sampling2d_65[0][0]',
#                                                                   'batch_normalization_336[0][0]']
#
#  conv2d_352 (Conv2D)            (None, 64, 64, 128)  442496      ['concatenate_60[0][0]']
#
#  batch_normalization_337 (Batch  (None, 64, 64, 128)  512        ['conv2d_352[0][0]']
#  Normalization)
#
#  activation_342 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_337[0][0]']
#
#  dropout_140 (Dropout)          (None, 64, 64, 128)  0           ['activation_342[0][0]']
#
#  conv2d_353 (Conv2D)            (None, 64, 64, 128)  147584      ['dropout_140[0][0]']
#
#  batch_normalization_338 (Batch  (None, 64, 64, 128)  512        ['conv2d_353[0][0]']
#  Normalization)
#
#  activation_343 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_338[0][0]']
#
#  conv2d_354 (Conv2D)            (None, 64, 64, 64)   8256        ['activation_343[0][0]']
#
#  batch_normalization_339 (Batch  (None, 64, 64, 64)  256         ['conv2d_354[0][0]']
#  Normalization)
#
#  activation_344 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_339[0][0]']
#
#  conv2d_356 (Conv2D)            (None, 64, 64, 64)   4160        ['activation_344[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 64, 64, 64)  36928       ['conv2d_356[0][0]']
#  spose)
#
#  conv2d_355 (Conv2D)            (None, 64, 64, 64)   16448       ['activation_334[0][0]']
#
#  add_37 (Add)                   (None, 64, 64, 64)   0           ['conv2d_transpose_5[0][0]',
#                                                                   'conv2d_355[0][0]']
#
#  activation_345 (Activation)    (None, 64, 64, 64)   0           ['add_37[0][0]']
#
#  conv2d_357 (Conv2D)            (None, 64, 64, 1)    65          ['activation_345[0][0]']
#
#  activation_346 (Activation)    (None, 64, 64, 1)    0           ['conv2d_357[0][0]']
#
#  up_sampling2d_66 (UpSampling2D  (None, 128, 128, 1)  0          ['activation_346[0][0]']
#  )
#
#  lambda_5 (Lambda)              (None, 128, 128, 64  0           ['up_sampling2d_66[0][0]']
#                                 )
#
#  multiply_5 (Multiply)          (None, 128, 128, 64  0           ['lambda_5[0][0]',
#                                 )                                 'activation_334[0][0]']
#
#  conv2d_358 (Conv2D)            (None, 128, 128, 64  4160        ['multiply_5[0][0]']
#                                 )
#
#  up_sampling2d_67 (UpSampling2D  (None, 128, 128, 12  0          ['activation_343[0][0]']
#  )                              8)
#
#  batch_normalization_340 (Batch  (None, 128, 128, 64  256        ['conv2d_358[0][0]']
#  Normalization)                 )
#
#  concatenate_61 (Concatenate)   (None, 128, 128, 19  0           ['up_sampling2d_67[0][0]',
#                                 2)                                'batch_normalization_340[0][0]']
#
#  conv2d_359 (Conv2D)            (None, 128, 128, 64  110656      ['concatenate_61[0][0]']
#                                 )
#
#  batch_normalization_341 (Batch  (None, 128, 128, 64  256        ['conv2d_359[0][0]']
#  Normalization)                 )
#
#  activation_347 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_341[0][0]']
#                                 )
#
#  dropout_141 (Dropout)          (None, 128, 128, 64  0           ['activation_347[0][0]']
#                                 )
#
#  conv2d_360 (Conv2D)            (None, 128, 128, 64  36928       ['dropout_141[0][0]']
#                                 )
#
#  batch_normalization_342 (Batch  (None, 128, 128, 64  256        ['conv2d_360[0][0]']
#  Normalization)                 )
#
#  activation_348 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_342[0][0]']
#                                 )
#
#  conv2d_361 (Conv2D)            (None, 128, 128, 32  2080        ['activation_348[0][0]']
#                                 )
#
#  batch_normalization_343 (Batch  (None, 128, 128, 32  128        ['conv2d_361[0][0]']
#  Normalization)                 )
#
#  activation_349 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_343[0][0]']
#                                 )
#
#  conv2d_363 (Conv2D)            (None, 128, 128, 32  1056        ['activation_349[0][0]']
#                                 )
#
#  conv2d_transpose_6 (Conv2DTran  (None, 128, 128, 32  9248       ['conv2d_363[0][0]']
#  spose)                         )
#
#  conv2d_362 (Conv2D)            (None, 128, 128, 32  4128        ['activation_332[0][0]']
#                                 )
#
#  add_38 (Add)                   (None, 128, 128, 32  0           ['conv2d_transpose_6[0][0]',
#                                 )                                 'conv2d_362[0][0]']
#
#  activation_350 (Activation)    (None, 128, 128, 32  0           ['add_38[0][0]']
#                                 )
#
#  conv2d_364 (Conv2D)            (None, 128, 128, 1)  33          ['activation_350[0][0]']
#
#  activation_351 (Activation)    (None, 128, 128, 1)  0           ['conv2d_364[0][0]']
#
#  up_sampling2d_68 (UpSampling2D  (None, 256, 256, 1)  0          ['activation_351[0][0]']
#  )
#
#  lambda_6 (Lambda)              (None, 256, 256, 32  0           ['up_sampling2d_68[0][0]']
#                                 )
#
#  multiply_6 (Multiply)          (None, 256, 256, 32  0           ['lambda_6[0][0]',
#                                 )                                 'activation_332[0][0]']
#
#  conv2d_365 (Conv2D)            (None, 256, 256, 32  1056        ['multiply_6[0][0]']
#                                 )
#
#  up_sampling2d_69 (UpSampling2D  (None, 256, 256, 64  0          ['activation_348[0][0]']
#  )                              )
#
#  batch_normalization_344 (Batch  (None, 256, 256, 32  128        ['conv2d_365[0][0]']
#  Normalization)                 )
#
#  concatenate_62 (Concatenate)   (None, 256, 256, 96  0           ['up_sampling2d_69[0][0]',
#                                 )                                 'batch_normalization_344[0][0]']
#
#  conv2d_366 (Conv2D)            (None, 256, 256, 32  27680       ['concatenate_62[0][0]']
#                                 )
#
#  batch_normalization_345 (Batch  (None, 256, 256, 32  128        ['conv2d_366[0][0]']
#  Normalization)                 )
#
#  activation_352 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_345[0][0]']
#                                 )
#
#  dropout_142 (Dropout)          (None, 256, 256, 32  0           ['activation_352[0][0]']
#                                 )
#
#  conv2d_367 (Conv2D)            (None, 256, 256, 32  9248        ['dropout_142[0][0]']
#                                 )
#
#  batch_normalization_346 (Batch  (None, 256, 256, 32  128        ['conv2d_367[0][0]']
#  Normalization)                 )
#
#  activation_353 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_346[0][0]']
#                                 )
#
#  conv2d_368 (Conv2D)            (None, 256, 256, 16  528         ['activation_353[0][0]']
#                                 )
#
#  batch_normalization_347 (Batch  (None, 256, 256, 16  64         ['conv2d_368[0][0]']
#  Normalization)                 )
#
#  activation_354 (Activation)    (None, 256, 256, 16  0           ['batch_normalization_347[0][0]']
#                                 )
#
#  conv2d_370 (Conv2D)            (None, 256, 256, 16  272         ['activation_354[0][0]']
#                                 )
#
#  conv2d_transpose_7 (Conv2DTran  (None, 256, 256, 16  2320       ['conv2d_370[0][0]']
#  spose)                         )
#
#  conv2d_369 (Conv2D)            (None, 256, 256, 16  1040        ['activation_330[0][0]']
#                                 )
#
#  add_39 (Add)                   (None, 256, 256, 16  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 'conv2d_369[0][0]']
#
#  activation_355 (Activation)    (None, 256, 256, 16  0           ['add_39[0][0]']
#                                 )
#
#  conv2d_371 (Conv2D)            (None, 256, 256, 1)  17          ['activation_355[0][0]']
#
#  activation_356 (Activation)    (None, 256, 256, 1)  0           ['conv2d_371[0][0]']
#
#  up_sampling2d_70 (UpSampling2D  (None, 512, 512, 1)  0          ['activation_356[0][0]']
#  )
#
#  lambda_7 (Lambda)              (None, 512, 512, 16  0           ['up_sampling2d_70[0][0]']
#                                 )
#
#  multiply_7 (Multiply)          (None, 512, 512, 16  0           ['lambda_7[0][0]',
#                                 )                                 'activation_330[0][0]']
#
#  conv2d_372 (Conv2D)            (None, 512, 512, 16  272         ['multiply_7[0][0]']
#                                 )
#
#  up_sampling2d_71 (UpSampling2D  (None, 512, 512, 32  0          ['activation_353[0][0]']
#  )                              )
#
#  batch_normalization_348 (Batch  (None, 512, 512, 16  64         ['conv2d_372[0][0]']
#  Normalization)                 )
#
#  concatenate_63 (Concatenate)   (None, 512, 512, 48  0           ['up_sampling2d_71[0][0]',
#                                 )                                 'batch_normalization_348[0][0]']
#
#  conv2d_373 (Conv2D)            (None, 512, 512, 16  6928        ['concatenate_63[0][0]']
#                                 )
#
#  batch_normalization_349 (Batch  (None, 512, 512, 16  64         ['conv2d_373[0][0]']
#  Normalization)                 )
#
#  activation_357 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_349[0][0]']
#                                 )
#
#  dropout_143 (Dropout)          (None, 512, 512, 16  0           ['activation_357[0][0]']
#                                 )
#
#  conv2d_374 (Conv2D)            (None, 512, 512, 16  2320        ['dropout_143[0][0]']
#                                 )
#
#  batch_normalization_350 (Batch  (None, 512, 512, 16  64         ['conv2d_374[0][0]']
#  Normalization)                 )
#
#  activation_358 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_350[0][0]']
#                                 )
#
#  conv2d_375 (Conv2D)            (None, 512, 512, 1)  17          ['activation_358[0][0]']
#
#  batch_normalization_351 (Batch  (None, 512, 512, 1)  4          ['conv2d_375[0][0]']
#  Normalization)
#
#  activation_359 (Activation)    (None, 512, 512, 1)  0           ['batch_normalization_351[0][0]']
#
# ==================================================================================================
# Total params: 2,341,513
# Trainable params: 2,337,607
# Non-trainable params: 3,906
# __________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-4d8c905dd4dd> in <module>
#      86       IoU = []
#      87       for label in labels:
# ---> 88           jaccard = jaccard_score(y_pred.flatten(),y_true.flatten(), pos_label=label, average='weighted')
#      89           IoU.append(jaccard)
#      90       IoU = np.mean(IoU) #jacard/IoU of single image
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in jaccard_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#     788     array([1. , 0. , 0.33...])
#     789     """
# --> 790     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#     791     samplewise = average == "samples"
#     792     MCM = multilabel_confusion_matrix(
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1346         raise ValueError("average has to be one of " + str(average_options))
#    1347
# -> 1348     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1349     # Convert to Python primitive type to avoid NumPy type / Python str
#    1350     # comparison. See https://github.com/numpy/numpy/issues/6784
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
# --> 334             % [int(l) for l in lengths]
#     335         )
#     336
#
# ValueError: Found input variables with inconsistent numbers of samples: [262144, 786432]

# %%
from datetime import datetime 
reconstructed_image = []
test_img = skimage.io.imread('/content/drive/MyDrive/training/images/cju0qkwl35piu0993l0dewei2.jpg') #test image

predicted_patches = []
start = datetime.now()   

test = test_img[:,:,1] #selecting green channel
test = clahe_equalized(test) #applying CLAHE
SIZE_X = (test_img.shape[1]//patch_size)*patch_size #getting size multiple of patch size
SIZE_Y = (test_img.shape[0]//patch_size)*patch_size #getting size multiple of patch size
test = cv2.resize(test, (SIZE_X, SIZE_Y))        
test = np.array(test)
patches = patchify(test, (patch_size, patch_size), step=patch_size) #create patches(patch_sizexpatch_sizex1)

for i in range(patches.shape[0]):
      for j in range(patches.shape[1]):
          single_patch = patches[i,j,:,:]
          single_patch_norm = (single_patch.astype('float32')) / 255.
          single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
          single_patch_input = np.expand_dims(single_patch_norm, 0)
          single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8) #predict on single patch
          predicted_patches.append(single_patch_prediction)
predicted_patches = np.array(predicted_patches)
predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patch_size,patch_size) )
reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) #join patches to form whole img

stop = datetime.now()
print('Execution time: ',(stop-start)) #computation time

plt.subplot(121)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.imshow(test_img)
plt.subplot(122)
plt.title('Prediction')
plt.xticks([])
plt.yticks([])
plt.imshow(reconstructed_image,cmap='gray')

plt.show()
# Out:
# Execution time:  0:00:00.064959

# %%
#checking segmentation results
import random
test_img_number = random.randint(0, len(testimg))
plt.figure(figsize=(20, 18))
plt.subplot(123)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.imshow(testimg[test_img_number])
plt.subplot(011)
plt.title('Ground Truth')
plt.xticks([])
plt.yticks([])
plt.imshow(ground_truth[test_img_number],cmap='gray')
plt.subplot(022)
plt.title('Prediction')
plt.xticks([])
plt.yticks([])
plt.imshow(prediction[test_img_number],cmap='gray')

plt.show()
