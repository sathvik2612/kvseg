# %%
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras import backend as K


#convolutional block
def conv_block(x, kernelsize, filters, dropout, batchnorm=False): 
    conv = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding="same")(x)
    if batchnorm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)
    conv = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding="same")(conv)
    if batchnorm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    return conv


#residual convolutional block
def res_conv_block(x, kernelsize, filters, dropout, batchnorm=False):
    conv1 = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding='same')(x)
    if batchnorm is True:
        conv1 = layers.BatchNormalization(axis=3)(conv1)
    conv1 = layers.Activation('relu')(conv1)    
    conv2 = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding='same')(conv1)
    if batchnorm is True:
        conv2 = layers.BatchNormalization(axis=3)(conv2)
        conv2 = layers.Activation("relu")(conv2)
    if dropout > 0:
        conv2 = layers.Dropout(dropout)(conv2)
        
    #skip connection    
    shortcut = layers.Conv2D(filters, kernel_size=(1, 1), kernel_initializer='he_normal', padding='same')(x)
    if batchnorm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)
    shortcut = layers.Activation("relu")(shortcut)
    respath = layers.add([shortcut, conv2])       
    return respath


#gating signal for attention unit
def gatingsignal(input, out_size, batchnorm=False):
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batchnorm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

#attention unit/block based on soft attention
def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), kernel_initializer='he_normal', padding='same')(x) 
    shape_theta_x = K.int_shape(theta_x)
    phi_g = layers.Conv2D(inter_shape, (1, 1), kernel_initializer='he_normal', padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3), strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]), kernel_initializer='he_normal', padding='same')(phi_g)
    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), kernel_initializer='he_normal', padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg) 
    upsample_psi = layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3), arguments={'repnum': shape_x[3]})(upsample_psi)                          
    y = layers.multiply([upsample_psi, x])
    result = layers.Conv2D(shape_x[3], (1, 1), kernel_initializer='he_normal', padding='same')(y)
    attenblock = layers.BatchNormalization()(result)
    return attenblock

#Simple U-NET
def unetmodel(input_shape, dropout=0.2, batchnorm=True):    
    
    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2
    
    inputs = layers.Input(input_shape)    

    # Downsampling layers
    dn_1 = conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    pool_1 = layers.MaxPooling2D(pool_size=(2,2))(dn_1)
    
    dn_2 = conv_block(pool_1, kernelsize, filters[1], dropout, batchnorm)
    pool_2 = layers.MaxPooling2D(pool_size=(2,2))(dn_2)
    
    dn_3 = conv_block(pool_2, kernelsize, filters[2], dropout, batchnorm)
    pool_3 = layers.MaxPooling2D(pool_size=(2,2))(dn_3)
    
    dn_4 = conv_block(pool_3, kernelsize, filters[3], dropout, batchnorm)
    pool_4 = layers.MaxPooling2D(pool_size=(2,2))(dn_4)
    
    dn_5 = conv_block(pool_4, kernelsize, filters[4], dropout, batchnorm)

    # Upsampling layers   
    up_5 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_5)
    up_5 = layers.concatenate([up_5, dn_4], axis=3)
    up_conv_5 = conv_block(up_5, kernelsize, filters[3], dropout, batchnorm)
    
    up_4 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_5)
    up_4 = layers.concatenate([up_4, dn_3], axis=3)
    up_conv_4 = conv_block(up_4, kernelsize, filters[2], dropout, batchnorm)
       
    up_3 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_4)
    up_3 = layers.concatenate([up_3, dn_2], axis=3)
    up_conv_3 = conv_block(up_3, kernelsize, filters[1], dropout, batchnorm)
    
    up_2 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_3)
    up_2 = layers.concatenate([up_2, dn_1], axis=3)
    up_conv_2 = conv_block(up_2, kernelsize, filters[0], dropout, batchnorm)    
   
    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv_2)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final)  

    model = models.Model(inputs=[inputs], outputs=[outputs])
    model.summary()        
    return model

    
#Attention U-NET
def attentionunet(input_shape, dropout=0.2, batchnorm=True):
    
    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2

    inputs = layers.Input(input_shape) 

    # Downsampling layers    
    dn_1 = conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    pool_1 = layers.MaxPooling2D(pool_size=(2,2))(dn_1)
    
    dn_2 = conv_block(pool_1, kernelsize, filters[1], dropout, batchnorm)
    pool_2 = layers.MaxPooling2D(pool_size=(2,2))(dn_2)
    
    dn_3 = conv_block(pool_2, kernelsize, filters[2], dropout, batchnorm)
    pool_3 = layers.MaxPooling2D(pool_size=(2,2))(dn_3)
    
    dn_4 = conv_block(pool_3, kernelsize, filters[3], dropout, batchnorm)
    pool_4 = layers.MaxPooling2D(pool_size=(2,2))(dn_4)
    
    dn_5 = conv_block(pool_4, kernelsize, filters[4], dropout, batchnorm)

    # Upsampling layers    
    gating_5 = gatingsignal(dn_5, filters[3], batchnorm)
    att_5 = attention_block(dn_4, gating_5, filters[3])
    up_5 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_5)
    up_5 = layers.concatenate([up_5, att_5], axis=3)
    up_conv_5 = conv_block(up_5, kernelsize, filters[3], dropout, batchnorm)
    
    gating_4 = gatingsignal(up_conv_5, filters[2], batchnorm)
    att_4 = attention_block(dn_3, gating_4, filters[2])
    up_4 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_5)
    up_4 = layers.concatenate([up_4, att_4], axis=3)
    up_conv_4 = conv_block(up_4, kernelsize, filters[2], dropout, batchnorm)
   
    gating_3 = gatingsignal(up_conv_4, filters[1], batchnorm)
    att_3 = attention_block(dn_2, gating_3, filters[1])
    up_3 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_4)
    up_3 = layers.concatenate([up_3, att_3], axis=3)
    up_conv_3 = conv_block(up_3, kernelsize, filters[1], dropout, batchnorm)
    
    gating_2 = gatingsignal(up_conv_3, filters[0], batchnorm)
    att_2 = attention_block(dn_1, gating_2, filters[0])
    up_2 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_3)
    up_2 = layers.concatenate([up_2, att_2], axis=3)
    up_conv_2 = conv_block(up_2, kernelsize, filters[0], dropout, batchnorm)
    
    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv_2)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final)  

    model = models.Model(inputs=[inputs], outputs=[outputs])
    model.summary()       
    return model    

#Res-UNET
def residualunet(input_shape, dropout=0.2, batchnorm=True):

    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2

    inputs = layers.Input(input_shape) 

    # Downsampling layers    
    dn_conv1 = conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    dn_pool1 = layers.MaxPooling2D(pool_size=(2,2))(dn_conv1)

    dn_conv2 = res_conv_block(dn_pool1, kernelsize, filters[1], dropout, batchnorm)
    dn_pool2 = layers.MaxPooling2D(pool_size=(2,2))(dn_conv2)

    dn_conv3 = res_conv_block(dn_pool2, kernelsize, filters[2], dropout, batchnorm)
    dn_pool3 = layers.MaxPooling2D(pool_size=(2,2))(dn_conv3)

    dn_conv4 = res_conv_block(dn_pool3, kernelsize, filters[3], dropout, batchnorm)
    dn_pool4 = layers.MaxPooling2D(pool_size=(2,2))(dn_conv4)

    dn_conv5 = res_conv_block(dn_pool4, kernelsize, filters[4], dropout, batchnorm)
   
    # upsampling layers
    up_conv6 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_conv5)
    up_conv6 = layers.concatenate([up_conv6, dn_conv4], axis=3)
    up_conv6 = res_conv_block(up_conv6, kernelsize, filters[3], dropout, batchnorm)

    up_conv7 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv6)
    up_conv7 = layers.concatenate([up_conv7, dn_conv3], axis=3)
    up_conv7 = res_conv_block(up_conv7, kernelsize, filters[2], dropout, batchnorm)

    up_conv8 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv7)
    up_conv8 = layers.concatenate([up_conv8, dn_conv2], axis=3)
    up_conv8 = res_conv_block(up_conv8, kernelsize, filters[1], dropout, batchnorm)

    up_conv9 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv8)
    up_conv9 = layers.concatenate([up_conv9, dn_conv1], axis=3)
    up_conv9 = res_conv_block(up_conv9, kernelsize, filters[0], dropout, batchnorm)


    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv9)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final) 
    
    model = models.Model(inputs=[inputs], outputs=[outputs])
    model.summary()
    return model

#Residual-Attention UNET (RA-UNET)
def residual_attentionunet(input_shape, dropout=0.2, batchnorm=True):
    
    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2
    
    inputs = layers.Input(input_shape)    
    
    # Downsampling layers
    dn_1 = res_conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    pool1 = layers.MaxPooling2D(pool_size=(2,2))(dn_1)

    dn_2 = res_conv_block(pool1, kernelsize, filters[1], dropout, batchnorm)
    pool2 = layers.MaxPooling2D(pool_size=(2,2))(dn_2)

    dn_3 = res_conv_block(pool2, kernelsize, filters[2], dropout, batchnorm)
    pool3 = layers.MaxPooling2D(pool_size=(2,2))(dn_3)

    dn_4 = res_conv_block(pool3, kernelsize, filters[3], dropout, batchnorm)
    pool4 = layers.MaxPooling2D(pool_size=(2,2))(dn_4)

    dn_5 = res_conv_block(pool4, kernelsize, filters[4], dropout, batchnorm)

    # Upsampling layers    
    gating_5 = gatingsignal(dn_5, filters[3], batchnorm)
    att_5 = attention_block(dn_4, gating_5, filters[3])
    up_5 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_5)
    up_5 = layers.concatenate([up_5, att_5], axis=3)
    up_conv_5 = res_conv_block(up_5, kernelsize, filters[3], dropout, batchnorm)
    
    gating_4 = gatingsignal(up_conv_5, filters[2], batchnorm)
    att_4 = attention_block(dn_3, gating_4, filters[2])
    up_4 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_5)
    up_4 = layers.concatenate([up_4, att_4], axis=3)
    up_conv_4 = res_conv_block(up_4, kernelsize, filters[2], dropout, batchnorm)
   
    gating_3 = gatingsignal(up_conv_4, filters[1], batchnorm)
    att_3 = attention_block(dn_2, gating_3, filters[1])
    up_3 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_4)
    up_3 = layers.concatenate([up_3, att_3], axis=3)
    up_conv_3 = res_conv_block(up_3, kernelsize, filters[1], dropout, batchnorm)
    
    gating_2 = gatingsignal(up_conv_3, filters[0], batchnorm)
    att_2 = attention_block(dn_1, gating_2, filters[0])
    up_2 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_3)
    up_2 = layers.concatenate([up_2, att_2], axis=3)
    up_conv_2 = res_conv_block(up_2, kernelsize, filters[0], dropout, batchnorm)
   
    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv_2)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final)  

    model = models.Model(inputs=[inputs], outputs=[outputs])
    model.summary() 
    return model

# %%
from tensorflow.keras import backend as K
from sklearn.metrics import jaccard_score,confusion_matrix


def IoU_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

def IoU_loss(y_true, y_pred):
    return -IoU_coef(y_true, y_pred)
 
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)
 
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)
  
def accuracy(y_true, y_pred):
    cm = confusion_matrix(y_true.flatten(),y_pred.flatten(), labels=[0, 1])
    acc = (cm[0,0]+cm[1,1])/(cm[0,0]+cm[0,1]+cm[1,0]+cm[1,1])
    return acc
  
def IoU(y_true, y_pred, labels = [0, 1]):
   IoU = []
   for label in labels:
      jaccard = jaccard_score(y_pred.flatten(),y_true.flatten(), pos_label=label, average='weighted')
      IoU.append(jaccard)     
   return np.mean(IoU)

# %%
# !pip install patchify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: patchify in /usr/local/lib/python3.7/dist-packages (0.2.3)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.7/dist-packages (from patchify) (1.21.6)

# %%
import os
import cv2
import numpy as np
import skimage.io
from matplotlib import pyplot as plt
from patchify import patchify
from PIL import Image
np.random.seed(0) 


#CLAHE
def clahe_equalized(imgs):    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))    
    imgs_equalized = clahe.apply(imgs)
    return imgs_equalized


path1 = '/content/drive/MyDrive/training/images' #training images directory
path2 = '/content/drive/MyDrive/training/masks' #training masks directory

image_dataset = []
mask_dataset = [] 

patch_size = 512

images = sorted(os.listdir(path1)) 

for i, image_name in enumerate(images):  
   if image_name.endswith(".jpg"):                   
       image = skimage.io.imread(path1+"/"+image_name)  #Read image
       
       image = image[:,:,1] #selecting green channel
       image = clahe_equalized(image) #applying CLAHE
       

       SIZE_X = (image.shape[1]//patch_size)*patch_size #getting size multiple of patch size
       SIZE_Y = (image.shape[0]//patch_size)*patch_size #getting size multiple of patch size
       image = Image.fromarray(image)        
       image = image.resize((512, 512)) #resize image       
       image = np.array(image) 
       patches_img = patchify(image, (patch_size, patch_size), step=patch_size)  #create patches(patch_sizexpatch_sizex1)
            
       for i in range(patches_img.shape[0]):
           for j in range(patches_img.shape[1]):                        
               single_patch_img = patches_img[i,j,:,:]                 
               single_patch_img = (single_patch_img.astype('float32')) / 255.                    
               image_dataset.append(single_patch_img)

masks = sorted(os.listdir(path2))  
for i, mask_name in enumerate(masks):  
    if mask_name.endswith(".jpg"):                  
        mask = skimage.io.imread(path2+"/"+mask_name,as_gray=True)   #Read masks
        
        
        SIZE_X = (mask.shape[1]//patch_size)*patch_size #getting size multiple of patch size
        SIZE_Y = (mask.shape[0]//patch_size)*patch_size #getting size multiple of patch size
        mask = Image.fromarray(mask)        
        mask = mask.resize((512, 512))  #resize image
        mask = np.array(mask)
        patches_mask = patchify(mask, (patch_size, patch_size), step=patch_size)  #create patches(patch_sizexpatch_sizex1)
            
        for i in range(patches_mask.shape[0]):
            for j in range(patches_mask.shape[1]):                            
                single_patch_mask = patches_mask[i,j,:,:]
                single_patch_mask = (single_patch_mask.astype('float32'))/255. 
                mask_dataset.append(single_patch_mask) 
 
image_dataset = np.array(image_dataset)
mask_dataset =  np.array(mask_dataset)
image_dataset = np.expand_dims(image_dataset,axis=-1)
mask_dataset =  np.expand_dims(mask_dataset,axis=-1)


#importing models

from tensorflow.keras.optimizers import Adam


IMG_HEIGHT = patch_size
IMG_WIDTH = patch_size
IMG_CHANNELS = 1
input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

#model = unetmodel(input_shape)
#model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])

#model = residualunet(input_shape)
#model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])
#model = attentionunet(input_shape)
#model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])
model = residual_attentionunet(input_shape)
model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])


#splitting data into 70-30 ratio to validate training performance
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size=0.2, random_state=0)

#train model
history = model.fit(x_train, y_train, 
                    verbose=1,
                    batch_size = 16,
                    validation_data=(x_test, y_test ), 
                    shuffle=False,
                    epochs=100)

#training-validation loss curve
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(7,5))
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'y', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

#training-validation accuracy curve
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(7,5))
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'y', label='Validation Accuracy')
plt.title('Training and validation accuracies')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

#training-validation IoU curve
iou_coef = history.history['IoU_coef']
val_iou_coef = history.history['val_IoU_coef']
plt.figure(figsize=(7,5))
plt.plot(epochs, iou_coef, 'r', label='Training IoU')
plt.plot(epochs, val_iou_coef, 'y', label='Validation IoU')
plt.title('Training and validation IoU coefficients')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

#save model
#model.save('/content/drive/MyDrive/training/retina_Unet_150epochs.hdf5')
# Out:
# Model: "model_16"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_17 (InputLayer)          [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d_376 (Conv2D)            (None, 512, 512, 16  160         ['input_17[0][0]']
#                                 )
#
#  batch_normalization_352 (Batch  (None, 512, 512, 16  64         ['conv2d_376[0][0]']
#  Normalization)                 )
#
#  activation_360 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_352[0][0]']
#                                 )
#
#  conv2d_377 (Conv2D)            (None, 512, 512, 16  2320        ['activation_360[0][0]']
#                                 )
#
#  conv2d_378 (Conv2D)            (None, 512, 512, 16  32          ['input_17[0][0]']
#                                 )
#
#  batch_normalization_353 (Batch  (None, 512, 512, 16  64         ['conv2d_377[0][0]']
#  Normalization)                 )
#
#  batch_normalization_354 (Batch  (None, 512, 512, 16  64         ['conv2d_378[0][0]']
#  Normalization)                 )
#
#  activation_361 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_353[0][0]']
#                                 )
#
#  activation_362 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_354[0][0]']
#                                 )
#
#  dropout_144 (Dropout)          (None, 512, 512, 16  0           ['activation_361[0][0]']
#                                 )
#
#  add_40 (Add)                   (None, 512, 512, 16  0           ['activation_362[0][0]',
#                                 )                                 'dropout_144[0][0]']
#
#  max_pooling2d_64 (MaxPooling2D  (None, 256, 256, 16  0          ['add_40[0][0]']
#  )                              )
#
#  conv2d_379 (Conv2D)            (None, 256, 256, 32  4640        ['max_pooling2d_64[0][0]']
#                                 )
#
#  batch_normalization_355 (Batch  (None, 256, 256, 32  128        ['conv2d_379[0][0]']
#  Normalization)                 )
#
#  activation_363 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_355[0][0]']
#                                 )
#
#  conv2d_380 (Conv2D)            (None, 256, 256, 32  9248        ['activation_363[0][0]']
#                                 )
#
#  conv2d_381 (Conv2D)            (None, 256, 256, 32  544         ['max_pooling2d_64[0][0]']
#                                 )
#
#  batch_normalization_356 (Batch  (None, 256, 256, 32  128        ['conv2d_380[0][0]']
#  Normalization)                 )
#
#  batch_normalization_357 (Batch  (None, 256, 256, 32  128        ['conv2d_381[0][0]']
#  Normalization)                 )
#
#  activation_364 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_356[0][0]']
#                                 )
#
#  activation_365 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_357[0][0]']
#                                 )
#
#  dropout_145 (Dropout)          (None, 256, 256, 32  0           ['activation_364[0][0]']
#                                 )
#
#  add_41 (Add)                   (None, 256, 256, 32  0           ['activation_365[0][0]',
#                                 )                                 'dropout_145[0][0]']
#
#  max_pooling2d_65 (MaxPooling2D  (None, 128, 128, 32  0          ['add_41[0][0]']
#  )                              )
#
#  conv2d_382 (Conv2D)            (None, 128, 128, 64  18496       ['max_pooling2d_65[0][0]']
#                                 )
#
#  batch_normalization_358 (Batch  (None, 128, 128, 64  256        ['conv2d_382[0][0]']
#  Normalization)                 )
#
#  activation_366 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_358[0][0]']
#                                 )
#
#  conv2d_383 (Conv2D)            (None, 128, 128, 64  36928       ['activation_366[0][0]']
#                                 )
#
#  conv2d_384 (Conv2D)            (None, 128, 128, 64  2112        ['max_pooling2d_65[0][0]']
#                                 )
#
#  batch_normalization_359 (Batch  (None, 128, 128, 64  256        ['conv2d_383[0][0]']
#  Normalization)                 )
#
#  batch_normalization_360 (Batch  (None, 128, 128, 64  256        ['conv2d_384[0][0]']
#  Normalization)                 )
#
#  activation_367 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_359[0][0]']
#                                 )
#
#  activation_368 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_360[0][0]']
#                                 )
#
#  dropout_146 (Dropout)          (None, 128, 128, 64  0           ['activation_367[0][0]']
#                                 )
#
#  add_42 (Add)                   (None, 128, 128, 64  0           ['activation_368[0][0]',
#                                 )                                 'dropout_146[0][0]']
#
#  max_pooling2d_66 (MaxPooling2D  (None, 64, 64, 64)  0           ['add_42[0][0]']
#  )
#
#  conv2d_385 (Conv2D)            (None, 64, 64, 128)  73856       ['max_pooling2d_66[0][0]']
#
#  batch_normalization_361 (Batch  (None, 64, 64, 128)  512        ['conv2d_385[0][0]']
#  Normalization)
#
#  activation_369 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_361[0][0]']
#
#  conv2d_386 (Conv2D)            (None, 64, 64, 128)  147584      ['activation_369[0][0]']
#
#  conv2d_387 (Conv2D)            (None, 64, 64, 128)  8320        ['max_pooling2d_66[0][0]']
#
#  batch_normalization_362 (Batch  (None, 64, 64, 128)  512        ['conv2d_386[0][0]']
#  Normalization)
#
#  batch_normalization_363 (Batch  (None, 64, 64, 128)  512        ['conv2d_387[0][0]']
#  Normalization)
#
#  activation_370 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_362[0][0]']
#
#  activation_371 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_363[0][0]']
#
#  dropout_147 (Dropout)          (None, 64, 64, 128)  0           ['activation_370[0][0]']
#
#  add_43 (Add)                   (None, 64, 64, 128)  0           ['activation_371[0][0]',
#                                                                   'dropout_147[0][0]']
#
#  max_pooling2d_67 (MaxPooling2D  (None, 32, 32, 128)  0          ['add_43[0][0]']
#  )
#
#  conv2d_388 (Conv2D)            (None, 32, 32, 256)  295168      ['max_pooling2d_67[0][0]']
#
#  batch_normalization_364 (Batch  (None, 32, 32, 256)  1024       ['conv2d_388[0][0]']
#  Normalization)
#
#  activation_372 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_364[0][0]']
#
#  conv2d_389 (Conv2D)            (None, 32, 32, 256)  590080      ['activation_372[0][0]']
#
#  conv2d_390 (Conv2D)            (None, 32, 32, 256)  33024       ['max_pooling2d_67[0][0]']
#
#  batch_normalization_365 (Batch  (None, 32, 32, 256)  1024       ['conv2d_389[0][0]']
#  Normalization)
#
#  batch_normalization_366 (Batch  (None, 32, 32, 256)  1024       ['conv2d_390[0][0]']
#  Normalization)
#
#  activation_373 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_365[0][0]']
#
#  activation_374 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_366[0][0]']
#
#  dropout_148 (Dropout)          (None, 32, 32, 256)  0           ['activation_373[0][0]']
#
#  add_44 (Add)                   (None, 32, 32, 256)  0           ['activation_374[0][0]',
#                                                                   'dropout_148[0][0]']
#
#  conv2d_391 (Conv2D)            (None, 32, 32, 128)  32896       ['add_44[0][0]']
#
#  batch_normalization_367 (Batch  (None, 32, 32, 128)  512        ['conv2d_391[0][0]']
#  Normalization)
#
#  activation_375 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_367[0][0]']
#
#  conv2d_393 (Conv2D)            (None, 32, 32, 128)  16512       ['activation_375[0][0]']
#
#  conv2d_transpose_8 (Conv2DTran  (None, 32, 32, 128)  147584     ['conv2d_393[0][0]']
#  spose)
#
#  conv2d_392 (Conv2D)            (None, 32, 32, 128)  65664       ['add_43[0][0]']
#
#  add_45 (Add)                   (None, 32, 32, 128)  0           ['conv2d_transpose_8[0][0]',
#                                                                   'conv2d_392[0][0]']
#
#  activation_376 (Activation)    (None, 32, 32, 128)  0           ['add_45[0][0]']
#
#  conv2d_394 (Conv2D)            (None, 32, 32, 1)    129         ['activation_376[0][0]']
#
#  activation_377 (Activation)    (None, 32, 32, 1)    0           ['conv2d_394[0][0]']
#
#  up_sampling2d_72 (UpSampling2D  (None, 64, 64, 1)   0           ['activation_377[0][0]']
#  )
#
#  lambda_8 (Lambda)              (None, 64, 64, 128)  0           ['up_sampling2d_72[0][0]']
#
#  multiply_8 (Multiply)          (None, 64, 64, 128)  0           ['lambda_8[0][0]',
#                                                                   'add_43[0][0]']
#
#  conv2d_395 (Conv2D)            (None, 64, 64, 128)  16512       ['multiply_8[0][0]']
#
#  up_sampling2d_73 (UpSampling2D  (None, 64, 64, 256)  0          ['add_44[0][0]']
#  )
#
#  batch_normalization_368 (Batch  (None, 64, 64, 128)  512        ['conv2d_395[0][0]']
#  Normalization)
#
#  concatenate_64 (Concatenate)   (None, 64, 64, 384)  0           ['up_sampling2d_73[0][0]',
#                                                                   'batch_normalization_368[0][0]']
#
#  conv2d_396 (Conv2D)            (None, 64, 64, 128)  442496      ['concatenate_64[0][0]']
#
#  batch_normalization_369 (Batch  (None, 64, 64, 128)  512        ['conv2d_396[0][0]']
#  Normalization)
#
#  activation_378 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_369[0][0]']
#
#  conv2d_397 (Conv2D)            (None, 64, 64, 128)  147584      ['activation_378[0][0]']
#
#  conv2d_398 (Conv2D)            (None, 64, 64, 128)  49280       ['concatenate_64[0][0]']
#
#  batch_normalization_370 (Batch  (None, 64, 64, 128)  512        ['conv2d_397[0][0]']
#  Normalization)
#
#  batch_normalization_371 (Batch  (None, 64, 64, 128)  512        ['conv2d_398[0][0]']
#  Normalization)
#
#  activation_379 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_370[0][0]']
#
#  activation_380 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_371[0][0]']
#
#  dropout_149 (Dropout)          (None, 64, 64, 128)  0           ['activation_379[0][0]']
#
#  add_46 (Add)                   (None, 64, 64, 128)  0           ['activation_380[0][0]',
#                                                                   'dropout_149[0][0]']
#
#  conv2d_399 (Conv2D)            (None, 64, 64, 64)   8256        ['add_46[0][0]']
#
#  batch_normalization_372 (Batch  (None, 64, 64, 64)  256         ['conv2d_399[0][0]']
#  Normalization)
#
#  activation_381 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_372[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 64, 64, 64)   4160        ['activation_381[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 64, 64, 64)  36928       ['conv2d_401[0][0]']
#  spose)
#
#  conv2d_400 (Conv2D)            (None, 64, 64, 64)   16448       ['add_42[0][0]']
#
#  add_47 (Add)                   (None, 64, 64, 64)   0           ['conv2d_transpose_9[0][0]',
#                                                                   'conv2d_400[0][0]']
#
#  activation_382 (Activation)    (None, 64, 64, 64)   0           ['add_47[0][0]']
#
#  conv2d_402 (Conv2D)            (None, 64, 64, 1)    65          ['activation_382[0][0]']
#
#  activation_383 (Activation)    (None, 64, 64, 1)    0           ['conv2d_402[0][0]']
#
#  up_sampling2d_74 (UpSampling2D  (None, 128, 128, 1)  0          ['activation_383[0][0]']
#  )
#
#  lambda_9 (Lambda)              (None, 128, 128, 64  0           ['up_sampling2d_74[0][0]']
#                                 )
#
#  multiply_9 (Multiply)          (None, 128, 128, 64  0           ['lambda_9[0][0]',
#                                 )                                 'add_42[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 128, 128, 64  4160        ['multiply_9[0][0]']
#                                 )
#
#  up_sampling2d_75 (UpSampling2D  (None, 128, 128, 12  0          ['add_46[0][0]']
#  )                              8)
#
#  batch_normalization_373 (Batch  (None, 128, 128, 64  256        ['conv2d_403[0][0]']
#  Normalization)                 )
#
#  concatenate_65 (Concatenate)   (None, 128, 128, 19  0           ['up_sampling2d_75[0][0]',
#                                 2)                                'batch_normalization_373[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 128, 128, 64  110656      ['concatenate_65[0][0]']
#                                 )
#
#  batch_normalization_374 (Batch  (None, 128, 128, 64  256        ['conv2d_404[0][0]']
#  Normalization)                 )
#
#  activation_384 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_374[0][0]']
#                                 )
#
#  conv2d_405 (Conv2D)            (None, 128, 128, 64  36928       ['activation_384[0][0]']
#                                 )
#
#  conv2d_406 (Conv2D)            (None, 128, 128, 64  12352       ['concatenate_65[0][0]']
#                                 )
#
#  batch_normalization_375 (Batch  (None, 128, 128, 64  256        ['conv2d_405[0][0]']
#  Normalization)                 )
#
#  batch_normalization_376 (Batch  (None, 128, 128, 64  256        ['conv2d_406[0][0]']
#  Normalization)                 )
#
#  activation_385 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_375[0][0]']
#                                 )
#
#  activation_386 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_376[0][0]']
#                                 )
#
#  dropout_150 (Dropout)          (None, 128, 128, 64  0           ['activation_385[0][0]']
#                                 )
#
#  add_48 (Add)                   (None, 128, 128, 64  0           ['activation_386[0][0]',
#                                 )                                 'dropout_150[0][0]']
#
#  conv2d_407 (Conv2D)            (None, 128, 128, 32  2080        ['add_48[0][0]']
#                                 )
#
#  batch_normalization_377 (Batch  (None, 128, 128, 32  128        ['conv2d_407[0][0]']
#  Normalization)                 )
#
#  activation_387 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_377[0][0]']
#                                 )
#
#  conv2d_409 (Conv2D)            (None, 128, 128, 32  1056        ['activation_387[0][0]']
#                                 )
#
#  conv2d_transpose_10 (Conv2DTra  (None, 128, 128, 32  9248       ['conv2d_409[0][0]']
#  nspose)                        )
#
#  conv2d_408 (Conv2D)            (None, 128, 128, 32  4128        ['add_41[0][0]']
#                                 )
#
#  add_49 (Add)                   (None, 128, 128, 32  0           ['conv2d_transpose_10[0][0]',
#                                 )                                 'conv2d_408[0][0]']
#
#  activation_388 (Activation)    (None, 128, 128, 32  0           ['add_49[0][0]']
#                                 )
#
#  conv2d_410 (Conv2D)            (None, 128, 128, 1)  33          ['activation_388[0][0]']
#
#  activation_389 (Activation)    (None, 128, 128, 1)  0           ['conv2d_410[0][0]']
#
#  up_sampling2d_76 (UpSampling2D  (None, 256, 256, 1)  0          ['activation_389[0][0]']
#  )
#
#  lambda_10 (Lambda)             (None, 256, 256, 32  0           ['up_sampling2d_76[0][0]']
#                                 )
#
#  multiply_10 (Multiply)         (None, 256, 256, 32  0           ['lambda_10[0][0]',
#                                 )                                 'add_41[0][0]']
#
#  conv2d_411 (Conv2D)            (None, 256, 256, 32  1056        ['multiply_10[0][0]']
#                                 )
#
#  up_sampling2d_77 (UpSampling2D  (None, 256, 256, 64  0          ['add_48[0][0]']
#  )                              )
#
#  batch_normalization_378 (Batch  (None, 256, 256, 32  128        ['conv2d_411[0][0]']
#  Normalization)                 )
#
#  concatenate_66 (Concatenate)   (None, 256, 256, 96  0           ['up_sampling2d_77[0][0]',
#                                 )                                 'batch_normalization_378[0][0]']
#
#  conv2d_412 (Conv2D)            (None, 256, 256, 32  27680       ['concatenate_66[0][0]']
#                                 )
#
#  batch_normalization_379 (Batch  (None, 256, 256, 32  128        ['conv2d_412[0][0]']
#  Normalization)                 )
#
#  activation_390 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_379[0][0]']
#                                 )
#
#  conv2d_413 (Conv2D)            (None, 256, 256, 32  9248        ['activation_390[0][0]']
#                                 )
#
#  conv2d_414 (Conv2D)            (None, 256, 256, 32  3104        ['concatenate_66[0][0]']
#                                 )
#
#  batch_normalization_380 (Batch  (None, 256, 256, 32  128        ['conv2d_413[0][0]']
#  Normalization)                 )
#
#  batch_normalization_381 (Batch  (None, 256, 256, 32  128        ['conv2d_414[0][0]']
#  Normalization)                 )
#
#  activation_391 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_380[0][0]']
#                                 )
#
#  activation_392 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_381[0][0]']
#                                 )
#
#  dropout_151 (Dropout)          (None, 256, 256, 32  0           ['activation_391[0][0]']
#                                 )
#
#  add_50 (Add)                   (None, 256, 256, 32  0           ['activation_392[0][0]',
#                                 )                                 'dropout_151[0][0]']
#
#  conv2d_415 (Conv2D)            (None, 256, 256, 16  528         ['add_50[0][0]']
#                                 )
#
#  batch_normalization_382 (Batch  (None, 256, 256, 16  64         ['conv2d_415[0][0]']
#  Normalization)                 )
#
#  activation_393 (Activation)    (None, 256, 256, 16  0           ['batch_normalization_382[0][0]']
#                                 )
#
#  conv2d_417 (Conv2D)            (None, 256, 256, 16  272         ['activation_393[0][0]']
#                                 )
#
#  conv2d_transpose_11 (Conv2DTra  (None, 256, 256, 16  2320       ['conv2d_417[0][0]']
#  nspose)                        )
#
#  conv2d_416 (Conv2D)            (None, 256, 256, 16  1040        ['add_40[0][0]']
#                                 )
#
#  add_51 (Add)                   (None, 256, 256, 16  0           ['conv2d_transpose_11[0][0]',
#                                 )                                 'conv2d_416[0][0]']
#
#  activation_394 (Activation)    (None, 256, 256, 16  0           ['add_51[0][0]']
#                                 )
#
#  conv2d_418 (Conv2D)            (None, 256, 256, 1)  17          ['activation_394[0][0]']
#
#  activation_395 (Activation)    (None, 256, 256, 1)  0           ['conv2d_418[0][0]']
#
#  up_sampling2d_78 (UpSampling2D  (None, 512, 512, 1)  0          ['activation_395[0][0]']
#  )
#
#  lambda_11 (Lambda)             (None, 512, 512, 16  0           ['up_sampling2d_78[0][0]']
#                                 )
#
#  multiply_11 (Multiply)         (None, 512, 512, 16  0           ['lambda_11[0][0]',
#                                 )                                 'add_40[0][0]']
#
#  conv2d_419 (Conv2D)            (None, 512, 512, 16  272         ['multiply_11[0][0]']
#                                 )
#
#  up_sampling2d_79 (UpSampling2D  (None, 512, 512, 32  0          ['add_50[0][0]']
#  )                              )
#
#  batch_normalization_383 (Batch  (None, 512, 512, 16  64         ['conv2d_419[0][0]']
#  Normalization)                 )
#
#  concatenate_67 (Concatenate)   (None, 512, 512, 48  0           ['up_sampling2d_79[0][0]',
#                                 )                                 'batch_normalization_383[0][0]']
#
#  conv2d_420 (Conv2D)            (None, 512, 512, 16  6928        ['concatenate_67[0][0]']
#                                 )
#
#  batch_normalization_384 (Batch  (None, 512, 512, 16  64         ['conv2d_420[0][0]']
#  Normalization)                 )
#
#  activation_396 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_384[0][0]']
#                                 )
#
#  conv2d_421 (Conv2D)            (None, 512, 512, 16  2320        ['activation_396[0][0]']
#                                 )
#
#  conv2d_422 (Conv2D)            (None, 512, 512, 16  784         ['concatenate_67[0][0]']
#                                 )
#
#  batch_normalization_385 (Batch  (None, 512, 512, 16  64         ['conv2d_421[0][0]']
#  Normalization)                 )
#
#  batch_normalization_386 (Batch  (None, 512, 512, 16  64         ['conv2d_422[0][0]']
#  Normalization)                 )
#
#  activation_397 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_385[0][0]']
#                                 )
#
#  activation_398 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_386[0][0]']
#                                 )
#
#  dropout_152 (Dropout)          (None, 512, 512, 16  0           ['activation_397[0][0]']
#                                 )
#
#  add_52 (Add)                   (None, 512, 512, 16  0           ['activation_398[0][0]',
#                                 )                                 'dropout_152[0][0]']
#
#  conv2d_423 (Conv2D)            (None, 512, 512, 1)  17          ['add_52[0][0]']
#
#  batch_normalization_387 (Batch  (None, 512, 512, 1)  4          ['conv2d_423[0][0]']
#  Normalization)
#
#  activation_399 (Activation)    (None, 512, 512, 1)  0           ['batch_normalization_387[0][0]']
# ...
# Epoch 17/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0018 - accuracy: 0.7939 - IoU_coef: 0.0018 - val_loss: -0.0011 - val_accuracy: 0.8255 - val_IoU_coef: 0.0011
# Epoch 18/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0019 - accuracy: 0.7990 - IoU_coef: 0.0019 - val_loss: -8.5233e-04 - val_accuracy: 0.8294 - val_IoU_coef: 8.4867e-04
# Epoch 19/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0020 - accuracy: 0.7995 - IoU_coef: 0.0020 - val_loss: -0.0014 - val_accuracy: 0.8169 - val_IoU_coef: 0.0014
# Epoch 20/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0021 - accuracy: 0.8057 - IoU_coef: 0.0021 - val_loss: -0.0012 - val_accuracy: 0.8116 - val_IoU_coef: 0.0012
# Epoch 21/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0021 - accuracy: 0.8070 - IoU_coef: 0.0021 - val_loss: -0.0014 - val_accuracy: 0.8151 - val_IoU_coef: 0.0014
# Epoch 22/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0022 - accuracy: 0.8088 - IoU_coef: 0.0022 - val_loss: -0.0010 - val_accuracy: 0.8273 - val_IoU_coef: 0.0010
# Epoch 23/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0023 - accuracy: 0.8119 - IoU_coef: 0.0023 - val_loss: -0.0016 - val_accuracy: 0.8210 - val_IoU_coef: 0.0016
# Epoch 24/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0023 - accuracy: 0.8135 - IoU_coef: 0.0023 - val_loss: -0.0016 - val_accuracy: 0.8207 - val_IoU_coef: 0.0016
# Epoch 25/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0024 - accuracy: 0.8152 - IoU_coef: 0.0024 - val_loss: -0.0011 - val_accuracy: 0.8295 - val_IoU_coef: 0.0011
# Epoch 26/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0025 - accuracy: 0.8173 - IoU_coef: 0.0025 - val_loss: -0.0013 - val_accuracy: 0.8284 - val_IoU_coef: 0.0013
# Epoch 27/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0025 - accuracy: 0.8179 - IoU_coef: 0.0025 - val_loss: -8.6918e-04 - val_accuracy: 0.8300 - val_IoU_coef: 8.7056e-04
# Epoch 28/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0026 - accuracy: 0.8205 - IoU_coef: 0.0026 - val_loss: -0.0012 - val_accuracy: 0.8301 - val_IoU_coef: 0.0012
# Epoch 29/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0027 - accuracy: 0.8216 - IoU_coef: 0.0027 - val_loss: -0.0017 - val_accuracy: 0.8284 - val_IoU_coef: 0.0017
# Epoch 30/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0027 - accuracy: 0.8224 - IoU_coef: 0.0027 - val_loss: -0.0014 - val_accuracy: 0.8277 - val_IoU_coef: 0.0014
# Epoch 31/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0028 - accuracy: 0.8232 - IoU_coef: 0.0028 - val_loss: -0.0018 - val_accuracy: 0.8282 - val_IoU_coef: 0.0018
# Epoch 32/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0028 - accuracy: 0.8233 - IoU_coef: 0.0028 - val_loss: -0.0020 - val_accuracy: 0.8288 - val_IoU_coef: 0.0020
# Epoch 33/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0029 - accuracy: 0.8251 - IoU_coef: 0.0029 - val_loss: -0.0021 - val_accuracy: 0.8277 - val_IoU_coef: 0.0021
# Epoch 34/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0030 - accuracy: 0.8253 - IoU_coef: 0.0030 - val_loss: -0.0012 - val_accuracy: 0.8302 - val_IoU_coef: 0.0012
# Epoch 35/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0030 - accuracy: 0.8262 - IoU_coef: 0.0030 - val_loss: -0.0018 - val_accuracy: 0.8294 - val_IoU_coef: 0.0018
# Epoch 36/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0030 - accuracy: 0.8254 - IoU_coef: 0.0030 - val_loss: -0.0021 - val_accuracy: 0.8293 - val_IoU_coef: 0.0021
# Epoch 37/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0031 - accuracy: 0.8267 - IoU_coef: 0.0031 - val_loss: -0.0021 - val_accuracy: 0.8299 - val_IoU_coef: 0.0022
# Epoch 38/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0031 - accuracy: 0.8265 - IoU_coef: 0.0031 - val_loss: -0.0023 - val_accuracy: 0.8278 - val_IoU_coef: 0.0023
# Epoch 39/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0031 - accuracy: 0.8272 - IoU_coef: 0.0031 - val_loss: -0.0023 - val_accuracy: 0.8284 - val_IoU_coef: 0.0023
# Epoch 40/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0032 - accuracy: 0.8271 - IoU_coef: 0.0032 - val_loss: -0.0016 - val_accuracy: 0.8297 - val_IoU_coef: 0.0016
# Epoch 41/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0032 - accuracy: 0.8279 - IoU_coef: 0.0032 - val_loss: -0.0025 - val_accuracy: 0.8248 - val_IoU_coef: 0.0025
# Epoch 42/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0032 - accuracy: 0.8278 - IoU_coef: 0.0032 - val_loss: -0.0021 - val_accuracy: 0.8300 - val_IoU_coef: 0.0021
# Epoch 43/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0033 - accuracy: 0.8283 - IoU_coef: 0.0033 - val_loss: -0.0020 - val_accuracy: 0.8298 - val_IoU_coef: 0.0020
# Epoch 44/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0033 - accuracy: 0.8283 - IoU_coef: 0.0033 - val_loss: -0.0023 - val_accuracy: 0.8289 - val_IoU_coef: 0.0023
# Epoch 45/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0033 - accuracy: 0.8288 - IoU_coef: 0.0033 - val_loss: -0.0024 - val_accuracy: 0.8297 - val_IoU_coef: 0.0024
# Epoch 46/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0033 - accuracy: 0.8284 - IoU_coef: 0.0033 - val_loss: -0.0027 - val_accuracy: 0.8270 - val_IoU_coef: 0.0027
# Epoch 47/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0034 - accuracy: 0.8289 - IoU_coef: 0.0034 - val_loss: -0.0027 - val_accuracy: 0.8289 - val_IoU_coef: 0.0027
# Epoch 48/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0034 - accuracy: 0.8290 - IoU_coef: 0.0034 - val_loss: -0.0026 - val_accuracy: 0.8294 - val_IoU_coef: 0.0026
# Epoch 49/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0034 - accuracy: 0.8292 - IoU_coef: 0.0034 - val_loss: -0.0020 - val_accuracy: 0.8302 - val_IoU_coef: 0.0020
# Epoch 50/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0035 - accuracy: 0.8293 - IoU_coef: 0.0035 - val_loss: -0.0019 - val_accuracy: 0.8302 - val_IoU_coef: 0.0019
# Epoch 51/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0035 - accuracy: 0.8295 - IoU_coef: 0.0035 - val_loss: -0.0023 - val_accuracy: 0.8302 - val_IoU_coef: 0.0023
# Epoch 52/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0035 - accuracy: 0.8296 - IoU_coef: 0.0035 - val_loss: -0.0020 - val_accuracy: 0.8302 - val_IoU_coef: 0.0020
# Epoch 53/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0035 - accuracy: 0.8297 - IoU_coef: 0.0035 - val_loss: -0.0016 - val_accuracy: 0.8302 - val_IoU_coef: 0.0016
# Epoch 54/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0035 - accuracy: 0.8295 - IoU_coef: 0.0035 - val_loss: -0.0028 - val_accuracy: 0.8294 - val_IoU_coef: 0.0028
# Epoch 55/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0035 - accuracy: 0.8297 - IoU_coef: 0.0035 - val_loss: -0.0023 - val_accuracy: 0.8302 - val_IoU_coef: 0.0022
# Epoch 56/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0035 - accuracy: 0.8298 - IoU_coef: 0.0035 - val_loss: -0.0030 - val_accuracy: 0.8287 - val_IoU_coef: 0.0030
# Epoch 57/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0036 - accuracy: 0.8299 - IoU_coef: 0.0036 - val_loss: -0.0028 - val_accuracy: 0.8298 - val_IoU_coef: 0.0028
# Epoch 58/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0036 - accuracy: 0.8299 - IoU_coef: 0.0036 - val_loss: -0.0030 - val_accuracy: 0.8294 - val_IoU_coef: 0.0030
# Epoch 59/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0036 - accuracy: 0.8299 - IoU_coef: 0.0036 - val_loss: -0.0028 - val_accuracy: 0.8295 - val_IoU_coef: 0.0028
# Epoch 60/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0036 - accuracy: 0.8298 - IoU_coef: 0.0036 - val_loss: -0.0013 - val_accuracy: 0.8303 - val_IoU_coef: 0.0013
# Epoch 61/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0036 - accuracy: 0.8298 - IoU_coef: 0.0036 - val_loss: -0.0028 - val_accuracy: 0.8298 - val_IoU_coef: 0.0028
# Epoch 62/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0036 - accuracy: 0.8301 - IoU_coef: 0.0036 - val_loss: -0.0020 - val_accuracy: 0.8303 - val_IoU_coef: 0.0021
# Epoch 63/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0036 - accuracy: 0.8300 - IoU_coef: 0.0036 - val_loss: -0.0029 - val_accuracy: 0.8300 - val_IoU_coef: 0.0029
# Epoch 64/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0036 - accuracy: 0.8300 - IoU_coef: 0.0036 - val_loss: -0.0029 - val_accuracy: 0.8300 - val_IoU_coef: 0.0029
# Epoch 65/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0037 - accuracy: 0.8300 - IoU_coef: 0.0037 - val_loss: -0.0025 - val_accuracy: 0.8302 - val_IoU_coef: 0.0026
# Epoch 66/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0037 - accuracy: 0.8300 - IoU_coef: 0.0037 - val_loss: -0.0030 - val_accuracy: 0.8300 - val_IoU_coef: 0.0030
# Epoch 67/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0037 - accuracy: 0.8300 - IoU_coef: 0.0037 - val_loss: -0.0031 - val_accuracy: 0.8298 - val_IoU_coef: 0.0031
# Epoch 68/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0037 - accuracy: 0.8302 - IoU_coef: 0.0037 - val_loss: -0.0031 - val_accuracy: 0.8300 - val_IoU_coef: 0.0031
# Epoch 69/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0037 - accuracy: 0.8301 - IoU_coef: 0.0037 - val_loss: -0.0027 - val_accuracy: 0.8301 - val_IoU_coef: 0.0027
# Epoch 70/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0037 - accuracy: 0.8301 - IoU_coef: 0.0037 - val_loss: -0.0033 - val_accuracy: 0.8291 - val_IoU_coef: 0.0033
# Epoch 71/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0037 - accuracy: 0.8300 - IoU_coef: 0.0037 - val_loss: -0.0033 - val_accuracy: 0.8286 - val_IoU_coef: 0.0033
# Epoch 72/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0037 - accuracy: 0.8301 - IoU_coef: 0.0037 - val_loss: -0.0030 - val_accuracy: 0.8300 - val_IoU_coef: 0.0030
# Epoch 73/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0037 - accuracy: 0.8301 - IoU_coef: 0.0037 - val_loss: -0.0027 - val_accuracy: 0.8302 - val_IoU_coef: 0.0027
# Epoch 74/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0037 - accuracy: 0.8302 - IoU_coef: 0.0037 - val_loss: -0.0033 - val_accuracy: 0.8298 - val_IoU_coef: 0.0033
# Epoch 75/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0037 - accuracy: 0.8303 - IoU_coef: 0.0037 - val_loss: -0.0031 - val_accuracy: 0.8300 - val_IoU_coef: 0.0032
# Epoch 76/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0037 - accuracy: 0.8302 - IoU_coef: 0.0037 - val_loss: -0.0033 - val_accuracy: 0.8274 - val_IoU_coef: 0.0033
# Epoch 77/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0037 - accuracy: 0.8302 - IoU_coef: 0.0037 - val_loss: -0.0033 - val_accuracy: 0.8295 - val_IoU_coef: 0.0033
# Epoch 78/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0037 - accuracy: 0.8302 - IoU_coef: 0.0037 - val_loss: -0.0033 - val_accuracy: 0.8299 - val_IoU_coef: 0.0033
# Epoch 79/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0030 - val_accuracy: 0.8301 - val_IoU_coef: 0.0030
# Epoch 80/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0033 - val_accuracy: 0.8289 - val_IoU_coef: 0.0033
# Epoch 81/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8266 - val_IoU_coef: 0.0034
# Epoch 82/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0032 - val_accuracy: 0.8300 - val_IoU_coef: 0.0032
# Epoch 83/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0026 - val_accuracy: 0.8303 - val_IoU_coef: 0.0026
# Epoch 84/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8299 - val_IoU_coef: 0.0034
# Epoch 85/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8301 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8297 - val_IoU_coef: 0.0034
# Epoch 86/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0029 - val_accuracy: 0.8301 - val_IoU_coef: 0.0029
# Epoch 87/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8298 - val_IoU_coef: 0.0034
# Epoch 88/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0027 - val_accuracy: 0.8303 - val_IoU_coef: 0.0027
# Epoch 89/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8300 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8289 - val_IoU_coef: 0.0034
# Epoch 90/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0031 - val_accuracy: 0.8302 - val_IoU_coef: 0.0031
# Epoch 91/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0037 - accuracy: 0.8298 - IoU_coef: 0.0037 - val_loss: -0.0032 - val_accuracy: 0.8299 - val_IoU_coef: 0.0033
# Epoch 92/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8300 - IoU_coef: 0.0038 - val_loss: -0.0018 - val_accuracy: 0.8302 - val_IoU_coef: 0.0018
# Epoch 93/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0022 - val_accuracy: 0.8303 - val_IoU_coef: 0.0023
# Epoch 94/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8302 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8299 - val_IoU_coef: 0.0034
# Epoch 95/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0032 - val_accuracy: 0.8303 - val_IoU_coef: 0.0032
# Epoch 96/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0031 - val_accuracy: 0.8303 - val_IoU_coef: 0.0031
# Epoch 97/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0034 - val_accuracy: 0.8300 - val_IoU_coef: 0.0034
# Epoch 98/100
# 50/50 [==============================] - 34s 674ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8295 - val_IoU_coef: 0.0035
# Epoch 99/100
# 50/50 [==============================] - 34s 673ms/step - loss: -0.0038 - accuracy: 0.8303 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8250 - val_IoU_coef: 0.0035
# Epoch 100/100
# 50/50 [==============================] - 34s 672ms/step - loss: -0.0038 - accuracy: 0.8304 - IoU_coef: 0.0038 - val_loss: -0.0035 - val_accuracy: 0.8301 - val_IoU_coef: 0.0035

# %%
model.save('resatt.h5')

# %%
import os
import cv2
import numpy as np
import skimage.io
from matplotlib import pyplot as plt
from patchify import patchify, unpatchify
np.random.seed(0)

# CLAHE
def clahe_equalized(imgs):    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))    
    imgs_equalized = clahe.apply(imgs)
    return imgs_equalized

patch_size = 512

#loading model architectures

from tensorflow.keras.optimizers import Adam


IMG_HEIGHT = patch_size
IMG_WIDTH = patch_size
IMG_CHANNELS = 1

input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

model = attention_residualunet(input_shape) #/residualunet(input_shape)/attentionunet(input_shape)/attention_residualunet(input_shape) 
model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])
model.load_weights('/content/resatt.h5') #loading weights


path1 = '/content/drive/MyDrive/training/images/'    #test dataset images directory path
path2 = '/content/drive/MyDrive/training/masks/'     #test dataset mask directory path


from sklearn.metrics import jaccard_score,confusion_matrix

testimg = []
ground_truth = []
prediction = []
global_IoU = []
global_accuracy = []

testimages = sorted(os.listdir(path1))
testmasks =  sorted(os.listdir(path2))

for idx, image_name in enumerate(testimages):  
   if image_name.endswith(".jpg"):  
      predicted_patches = []
      test_img = skimage.io.imread(path1+"/"+image_name)
     
      test = test_img[:,:,1] #selecting green channel
      test = clahe_equalized(test) #applying CLAHE
      SIZE_X = (test_img.shape[1]//patch_size)*patch_size #getting size multiple of patch size
      SIZE_Y = (test_img.shape[0]//patch_size)*patch_size #getting size multiple of patch size
      test = cv2.resize(test, (SIZE_X, SIZE_Y))
      testimg.append(test)           
      test = np.array(test)

      patches = patchify(test, (patch_size, patch_size), step=patch_size) #create patches(patch_sizexpatch_sizex1)

      for i in range(patches.shape[0]):
                for j in range(patches.shape[1]):
                  single_patch = patches[i,j,:,:]
                  single_patch_norm = (single_patch.astype('float32')) / 255.
                  single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
                  single_patch_input = np.expand_dims(single_patch_norm, 0)
                  single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8) #predict on single patch
                  predicted_patches.append(single_patch_prediction)
      predicted_patches = np.array(predicted_patches)
      predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patch_size,patch_size) )
      reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) #join patches to form whole img
      prediction.append(reconstructed_image) 

      groundtruth=[]
      groundtruth = skimage.io.imread(path2+'/'+testmasks[idx]) #reading mask of the test img      
      SIZE_X = (groundtruth.shape[1]//patch_size)*patch_size 
      SIZE_Y = (groundtruth.shape[0]//patch_size)*patch_size  
      groundtruth = cv2.resize(groundtruth, (SIZE_X, SIZE_Y))  
      ground_truth.append(groundtruth)

      y_true = groundtruth
      y_pred = reconstructed_image
      labels = [0, 1]
      IoU = []
      for label in labels:
          jaccard = jaccard_score(y_pred.flatten(),y_true.flatten(), pos_label=label, average='weighted')
          IoU.append(jaccard)
      IoU = np.mean(IoU) #jacard/IoU of single image
      global_IoU.append(IoU)

      cm=[]
      accuracy = []
      cm = confusion_matrix(y_true.flatten(),y_pred.flatten(), labels=[0, 1])
      accuracy = (cm[0,0]+cm[1,1])/(cm[0,0]+cm[0,1]+cm[1,0]+cm[1,1]) #accuracy of single image
      global_accuracy.append(accuracy)


avg_acc =  np.mean(global_accuracy)
mean_IoU = np.mean(global_IoU)

print('Average accuracy is',avg_acc)
print('mean IoU is',mean_IoU)






#prediction on single image
from datetime import datetime 
reconstructed_image = []
test_img = skimage.io.imread('/content/drive/MyDrive/DRIVE/test/images/01_test.tif') #test image

predicted_patches = []
start = datetime.now()   

test = test_img[:,:,1] #selecting green channel
test = clahe_equalized(test) #applying CLAHE
SIZE_X = (test_img.shape[1]//patch_size)*patch_size #getting size multiple of patch size
SIZE_Y = (test_img.shape[0]//patch_size)*patch_size #getting size multiple of patch size
test = cv2.resize(test, (SIZE_X, SIZE_Y))        
test = np.array(test)
patches = patchify(test, (patch_size, patch_size), step=patch_size) #create patches(patch_sizexpatch_sizex1)

for i in range(patches.shape[0]):
      for j in range(patches.shape[1]):
          single_patch = patches[i,j,:,:]
          single_patch_norm = (single_patch.astype('float32')) / 255.
          single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
          single_patch_input = np.expand_dims(single_patch_norm, 0)
          single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8) #predict on single patch
          predicted_patches.append(single_patch_prediction)
predicted_patches = np.array(predicted_patches)
predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patch_size,patch_size) )
reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) #join patches to form whole img

stop = datetime.now()
print('Execution time: ',(stop-start)) #computation time

plt.subplot(121)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.imshow(test_img)
plt.subplot(122)
plt.title('Prediction')
plt.xticks([])
plt.yticks([])
plt.imshow(reconstructed_image,cmap='gray')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-077b1bc67458> in <module>
#      26 input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
#      27
# ---> 28 model = attention_residualunet(input_shape) #/residualunet(input_shape)/attentionunet(input_shape)/attention_residualunet(input_shape)
#      29 model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])
#      30 model.load_weights('/content/resatt.h5') #loading weights
#
# NameError: name 'attention_residualunet' is not defined

# %%
from datetime import datetime 
reconstructed_image = []
test_img = skimage.io.imread('/content/drive/MyDrive/training/images/cju0qkwl35piu0993l0dewei2.jpg') #test image

predicted_patches = []
start = datetime.now()   

test = test_img[:,:,1] #selecting green channel
test = clahe_equalized(test) #applying CLAHE
SIZE_X = (test_img.shape[1]//patch_size)*patch_size #getting size multiple of patch size
SIZE_Y = (test_img.shape[0]//patch_size)*patch_size #getting size multiple of patch size
test = cv2.resize(test, (SIZE_X, SIZE_Y))        
test = np.array(test)
patches = patchify(test, (patch_size, patch_size), step=patch_size) #create patches(patch_sizexpatch_sizex1)

for i in range(patches.shape[0]):
      for j in range(patches.shape[1]):
          single_patch = patches[i,j,:,:]
          single_patch_norm = (single_patch.astype('float32')) / 255.
          single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
          single_patch_input = np.expand_dims(single_patch_norm, 0)
          single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8) #predict on single patch
          predicted_patches.append(single_patch_prediction)
predicted_patches = np.array(predicted_patches)
predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patch_size,patch_size) )
reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) #join patches to form whole img

stop = datetime.now()
print('Execution time: ',(stop-start)) #computation time

plt.subplot(121)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.imshow(test_img)
plt.subplot(122)
plt.title('Prediction')
plt.xticks([])
plt.yticks([])
plt.imshow(reconstructed_image,cmap='gray')

plt.show()
# Out:
# Execution time:  0:00:00.069614

# %%
#checking segmentation results
import random
test_img_number = random.randint(0, len(testimg))
plt.figure(figsize=(20, 18))
plt.subplot(123)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.imshow(testimg[test_img_number])
plt.subplot(011)
plt.title('Ground Truth')
plt.xticks([])
plt.yticks([])
plt.imshow(ground_truth[test_img_number],cmap='gray')
plt.subplot(022)
plt.title('Prediction')
plt.xticks([])
plt.yticks([])
plt.imshow(prediction[test_img_number],cmap='gray')

plt.show()
# Out:
#   File "<ipython-input-75-43443037c364>", line 10
#     plt.subplot(011)
#                   ^
# SyntaxError: invalid token
